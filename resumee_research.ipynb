# %%
import copy
import json
import re

# TODO
# --OK Usar idioma de la oferta 
# --ok Afinar y aprobar en una segunda pasada la job description para evitar repeticiones, concatenaciones de keywords sin sentido
# traducir titulos de curriculum
# --OK Extraer soft skills generales (evitar usarlas en las job description?)
# --OK usar modelo qwen3:32b 
# optimizar tags html en template
# leer curriculum original para escrapear los datos
# --OK generar pdf
# generar documento editable word? odf? para corregir

wpd_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.document.wpd"
cva_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv_adapted.json"
cv_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.html"
pdf_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.pdf"

cv_file_path = 'data/cv_data_es.json'
soft_skill_file_path = 'data/soft_skill_es.json'
cv_data = {}
soft_skill = {}
# Load JSON file into a dictionary
with open(cv_file_path, 'r') as f:
    cv_data = json.load(f)
with open(soft_skill_file_path, 'r') as f:
    soft_skill = json.load(f)

base_skills_list = [item for value_list in soft_skill.values() for item in value_list]

cv_adapted = copy.deepcopy(cv_data)

use_cache=True

job_offer_url = 'https://www.linkedin.com/jobs/view/4362181901'
# job_offer_url = 'https://www.linkedin.com/jobs/view/4317166787'
# job_offer_url = 'https://selection.uoc.edu/web/offersjob/offerdetails.aspx?offerID=5464EA521BB0E0207C9DA853CA6F8505F72B82E3D56D2CAD90882623EBEE1FA7'

# %%
from tools import web_operations
from langchain_core.documents import Document

document = web_operations.scrape_webpages.invoke(input={'url':job_offer_url, 'include_links':False })[0]
print(document.metadata['title'])
# Out:
# Webpage loaded from cache /tmp/53f5dafb53ab517e01e9e24435ac4a62.tmp
# DXC Technology hiring Analista técnico/funcional informático/a in Sant Cugat del Vallès, Catalonia, Spain | LinkedIn

# %%
from typing import Annotated, List, Dict, Any, Optional
from langchain_core.documents import Document
from langchain_core.messages import SystemMessage, HumanMessage
from typing import TypedDict, Literal
from pathlib import Path
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langfuse.langchain import CallbackHandler
import pickle
import json

# # Prompt para el analizador de ofertas
# job_analyzer_prompt = """You are a precise job offer analyzer. Your task is to extract and structure information from job offers according to the provided schema.

# Key instructions:
# 1. **Job Title Extraction**: Extract the exact job position title from the document
# 2. **Company Description**: Extract a Concise, clear, human-friendly and jargon-free company summary, focus on the company goals and values
# 3. **Job Functions**: Extract all job responsibilities exactly as written in the document
# 4. **Job Requirements**: Extract all formal requirements exactly as written in the document
# 5. **Language Detection**: Finally, detect the language of the text. It can be Spanish or Catalan or English

# Important: 
# - Never translate, Preserve all original wording and language
# - Extract verbatim content from the document
# - Return only the structured data matching the schema
# - Do not add any explanations or additional text

# Output Format:

# 1. **job_position_title**:
# 2. **company_description**:
# 3. **job_functions**:
#     - ''
# 4. **job_requirements**:
#     - ''
# 5. **language**: Spanish or Catalan or English

# /no_think
# """

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, temperature=0.0,  top_p=0.1, top_k=20, repeat_penalty=1.1, seed=42)

class JobOffer(BaseModel):
    language: Literal['Spanish', 'Catalan', 'English'] = Field(description="The detected language")
    job_position_title: str = Field(description="Job title")
    company_description: str = Field(description="Concise, clear, human-friendly and jargon-free company summary")
    job_functions: list[str] = Field(description="Verbatim job responsibilities")
    job_requirements: list[str] = Field(description="Verbatim formal requirements")

def extract_job_parts(content) -> JobOffer:
    """Agente que analiza la oferta laboral y extrae información"""
    
    try:
        return llm.with_structured_output(JobOffer).invoke(
            input = [
                # SystemMessage(content=job_analyzer_prompt),
                HumanMessage(content=content)
            ],
            config = config)    

    except Exception as e:
        print(f"Error: {e}")
        raise

job_offer = extract_job_parts(content = document.page_content)
display(job_offer.model_dump())

document.metadata.update(job_offer.model_dump())
with open(wpd_filepath(document.metadata['source']), 'wb') as f:
    pickle.dump(document, f)
# Out:
# {'language': 'Spanish',
#  'job_position_title': 'Analista técnico/funcional informático/a',
#  'company_description': 'DXC Technology es una compañía global de servicios profesionales cuya misión es liderar la transformación digital de nuestros clientes asesorándoles y guiándoles en la aplicación de la tecnología para obtener los mejores resultados que permitan incrementar la competitividad de sus empresas. Con más de 130.000 profesionales y expertos tecnólogos, colaborando en más de 70 países junto a una excepcional red de partners, somos capaces de ofrecer servicios y soluciones avanzadas de IT.',
#  'job_functions': ['Análisis de requisitos y diseño de soluciones informáticas',
#   'Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos',
#   'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos',
#   'Desarrollar y mantener plantillas y documentación estandarizada para agilizar el proceso de redacción',
#   'Participar en la definición de estrategias y enfoques para licitaciones, considerando las necesidades del cliente y los objetivos comerciales',
#   'Recopilar y analizar información relativa a licitaciones previas al objeto de mejorar las futuras propuestas a realizar'],
#  'job_requirements': ['Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI)',
#   'Experiencia en la realización de análisis funcionales y captura de requerimientos',
#   'Conocimientos técnicos sobre los principales componentes de administración electrónica del ámbito regional de Catalunya (CTTI, IMI, ACA, etc.)',
#   'Deseable disponer de conocimientos técnicos sobre arquitecturas Low Code (Outsystems, Appian, PowerPlatform)',
#   'Familiarizado con el uso de herramientas gráficas de modelaje de Arquitectura Empresarial (Archi, Visio, Draw.io o similares) y de modelaje de dominios funcionales (UML, Diagramas Entidad-Relación, Workflows, BPM, etc.)',
#   'Conocimientos en metodologías Gestión de Proyectos Lean/Agile (Scrum, Kanban, Dual Track, etc)',
#   'Conocimiento en metodologías de Gestión de Servicios TIC (ITIL, IT4IT, SecDevOps, etc.)',
#   'Experiencia utilizando herramientas de productividad de Microsoft (Word, Excel, PowerPoint, SharePoint, Planner, etc.) e Inteligencia Artificial (ChatGPT, Copilot 360, Gemini o similares) para automatizar y mejorar ciertos procesos de redacción de las ofertas',
#   'Excelentes habilidades de comunicación (especialmente escrita) en castellano y catalán',
#   'Habituado a trabajar en grupo de forma colaborativa',
#   'Capacidad resolutiva, proactividad, iniciativa y autonomía']}

# %%
keyword_extractor_prompt = """Extract the keywords *exactly as they appear* in the input text.
Follow these rules strictly:
- DO NOT change word forms (e.g., keep plural "percepciones", not singular "percepción").
- DO NOT lemmatize, stem, or normalize words.
- DO NOT translate or rephrase.
- Keep only the most relevant short and simple keywords from the field of computer science and project management.
- Only include words/phrases that appear directly in the text.
- Output the keywords in the same order as they appear, preserving original casing and accents.
- If a keyword is repeated, include it only once, preserving the first occurrence form.
/no_think"""

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, temperature=0.0,  top_p=0.1, top_k=20, repeat_penalty=1.1, seed=42)

class Keywords(BaseModel):
    keywords: list[str] =  Field(description="Verbatim short and simple keywords in the field of computer science and project management")

def extract_keywords(content) -> Keywords:
    """Agente que extrae las keywords de un texto"""
    
    try:
        return llm.with_structured_output(Keywords).invoke(
            input = [SystemMessage(content=keyword_extractor_prompt),
                HumanMessage(content=content)
            ],
            config = config)    

    except Exception as e:
        print(f"Error: {e}")
        raise

# content = 'Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI)'
content = 'Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos'
print(content)
print(extract_keywords(content))
# Out:
# Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos
# keywords=['Identificación', 'requisitos', 'ambigüedades', 'inconsistencias']

# %%
def get_item(id, item) -> dict:
    if isinstance(item,str):
        return {'id':id, 'title':item}
    return item


def extract_job_offer_keywords(job_offer, use_cache = True):

    id = 0

    for f in range(0,len(job_offer.job_functions)):
        item = get_item(id, job_offer.job_functions[f])
        item['keywords'] = extract_keywords(item['title']).keywords
        id = id + 1
        job_offer.job_functions[f] = item
        print(item)

    for f in range(0,len(job_offer.job_requirements)):
        item = get_item(id, job_offer.job_requirements[f])
        item['keywords'] = extract_keywords(item['title']).keywords
        id = id + 1
        job_offer.job_requirements[f] = item
        print(item)

extract_job_offer_keywords(job_offer, use_cache = use_cache)
# Out:
# {'id': 0, 'title': 'Análisis de requisitos y diseño de soluciones informáticas', 'keywords': ['Análisis', 'requisitos', 'diseño', 'soluciones', 'informáticas']}
# {'id': 1, 'title': 'Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos', 'keywords': ['Identificación', 'requisitos', 'ambigüedades', 'inconsistencias']}
# {'id': 2, 'title': 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos', 'keywords': ['Colaborar', 'equipos multidisciplinarios', 'redactar', 'revisar', 'propuestas técnicas', 'comerciales', 'licitaciones', 'desarrollo', 'proyectos informáticos', 'precisión', 'claridad', 'cumplimiento', 'requisitos']}
# {'id': 3, 'title': 'Desarrollar y mantener plantillas y documentación estandarizada para agilizar el proceso de redacción', 'keywords': ['plantillas', 'documentación', 'estandarizada', 'proceso', 'redacción']}
# {'id': 4, 'title': 'Participar en la definición de estrategias y enfoques para licitaciones, considerando las necesidades del cliente y los objetivos comerciales', 'keywords': ['Participar', 'definición', 'estrategias', 'enfoques', 'licitaciones', 'necesidades', 'cliente', 'objetivos', 'comerciales']}
# {'id': 5, 'title': 'Recopilar y analizar información relativa a licitaciones previas al objeto de mejorar las futuras propuestas a realizar', 'keywords': ['licitaciones', 'analizar', 'información', 'mejorar', 'propuestas']}
# {'id': 6, 'title': 'Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI)', 'keywords': ['Experiencia', 'redacción', 'elaboración', 'propuestas', 'técnicas', 'comerciales', 'licitaciones', 'desarrollo', 'proyectos', 'informáticos', 'CTTI']}
# {'id': 7, 'title': 'Experiencia en la realización de análisis funcionales y captura de requerimientos', 'keywords': ['Experiencia', 'análisis funcionales', 'captura de requerimientos']}
# {'id': 8, 'title': 'Conocimientos técnicos sobre los principales componentes de administración electrónica del ámbito regional de Catalunya (CTTI, IMI, ACA, etc.)', 'keywords': ['Conocimientos', 'técnicos', 'principales', 'componentes', 'administración', 'electrónica', 'ámbito', 'regional', 'Catalunya', 'CTTI', 'IMI', 'ACA']}
# {'id': 9, 'title': 'Deseable disponer de conocimientos técnicos sobre arquitecturas Low Code (Outsystems, Appian, PowerPlatform)', 'keywords': ['Low Code', 'Outsystems', 'Appian', 'PowerPlatform']}
# {'id': 10, 'title': 'Familiarizado con el uso de herramientas gráficas de modelaje de Arquitectura Empresarial (Archi, Visio, Draw.io o similares) y de modelaje de dominios funcionales (UML, Diagramas Entidad-Relación, Workflows, BPM, etc.)', 'keywords': ['Arquitectura Empresarial', 'Archi', 'Visio', 'Draw.io', 'modelaje de dominios funcionales', 'UML', 'Diagramas Entidad-Relación', 'Workflows', 'BPM']}
# {'id': 11, 'title': 'Conocimientos en metodologías Gestión de Proyectos Lean/Agile (Scrum, Kanban, Dual Track, etc)', 'keywords': ['Gestión de Proyectos', 'Lean', 'Agile', 'Scrum', 'Kanban', 'Dual Track']}
# {'id': 12, 'title': 'Conocimiento en metodologías de Gestión de Servicios TIC (ITIL, IT4IT, SecDevOps, etc.)', 'keywords': ['Gestión de Servicios TIC', 'ITIL', 'IT4IT', 'SecDevOps']}
# {'id': 13, 'title': 'Experiencia utilizando herramientas de productividad de Microsoft (Word, Excel, PowerPoint, SharePoint, Planner, etc.) e Inteligencia Artificial (ChatGPT, Copilot 360, Gemini o similares) para automatizar y mejorar ciertos procesos de redacción de las ofertas', 'keywords': ['Microsoft', 'Word', 'Excel', 'PowerPoint', 'SharePoint', 'Planner', 'Inteligencia Artificial', 'ChatGPT', 'Copilot 360', 'Gemini']}
# {'id': 14, 'title': 'Excelentes habilidades de comunicación (especialmente escrita) en castellano y catalán', 'keywords': ['Excelentes', 'habilidades', 'comunicación', 'escrita', 'castellano', 'catalán']}
# {'id': 15, 'title': 'Habituado a trabajar en grupo de forma colaborativa', 'keywords': ['grupo', 'colaborativa']}
# {'id': 16, 'title': 'Capacidad resolutiva, proactividad, iniciativa y autonomía', 'keywords': ['Capacidad resolutiva', 'proactividad', 'iniciativa', 'autonomía']}

# %%
kw_selector_prompt = """
INSTRUCTION: You MUST select ONLY keywords that EXACTLY appear in the list below.
DO NOT invent, paraphrase, or generate variants — only use the keywords explicitly listed.

keywords_list (you MUST use ONLY these):
{keywords_list}

always select al least one keyword from the keywords_list.

Examples of valid output: ["Python", "SQL"]
Examples of invalid output: ["Pytho", "SQL databases"] — avoid these at all costs!
"""

class KeywordsFit(BaseModel):
    keywords: list[str] =  Field(description="best fit keywords in keywords_list")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, temperature=0.0,  top_p=0.0, top_k=10, repeat_penalty=1.1, seed=42)

def select_keywords(content, keywords_list) -> list:
    """Agente que elije el mejor match de un keyword de una tarea"""
    try:
        result = llm.with_structured_output(KeywordsFit).invoke(
            input = [SystemMessage(content=kw_selector_prompt.format(keywords_list=keywords_list)),
                HumanMessage(content=content)
            ],
            config = config)    

        return [kw for kw in result.keywords if kw.lower() in keywords_list]

    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
tasks_kw = [t["keywords"] for t in job_offer.job_functions+job_offer.job_requirements]
keywords_list = list({cell.lower() for row in tasks_kw for cell in row})
keywords_list.sort()
# keywords_list = "\n".join(f"- {kw}" for kw in keywords)
assigned_kw = []

for e in range(len(cv_adapted['experiences'])):
    for t in range(len(cv_adapted['experiences'][e]['description'])):
        task = cv_adapted['experiences'][e]['description'][t]
        keywords = select_keywords(task, keywords_list)
        assigned_kw += keywords
        keywords_list = [kw for kw in keywords_list if kw not in keywords]
        cv_adapted['experiences'][e]['description'][t] = {'description':task, 'keywords':keywords}
        print(cv_adapted['experiences'][e]['description'][t])

assigned_kw = list(set(assigned_kw))
missing_kw = [kw for kw in keywords_list if kw not in assigned_kw ]

print('assigned:', len(assigned_kw), 'missing', len(missing_kw))
# Out:
# {'description': 'Elaboración de documentación para licitaciones e identificación de requisitos técnicos y funcionales.', 'keywords': ['elaboración', 'licitaciones', 'identificación', 'requisitos']}
# {'description': 'Coordinación de equipos técnicos corporativos y seguimiento de proyectos y servicios.', 'keywords': ['proyectos']}
# {'description': 'Facilitar la comunicación con proveedores externos para garantizar la calidad y cumplimiento de acuerdos.', 'keywords': ['comunicación', 'cumplimiento']}
# {'description': 'Impulso de la transformación digital y facilitar la transición a los usuarios hacia nuevas tecnologías.', 'keywords': []}
# {'description': 'Gestión de presupuestos y ejecución de proyectos según el Plan estratégico.', 'keywords': ['gestión de proyectos']}
# {'description': 'Evaluación y mitigación de riesgos en servicios y proyectos TIC.', 'keywords': ['gestión de servicios tic']}
# {'description': 'Propuesta y desarrollo de iniciativas de mejora continua.', 'keywords': ['propuestas técnicas', 'mejorar', 'iniciativa']}
# {'description': 'Gobernanza operativa para la gestión de recursos y despliegue de servicios.', 'keywords': []}
# {'description': 'Seguimiento operativo, resolución de incidencias y prevención de obsolescencia tecnológica.', 'keywords': ['precisión', 'proactividad', 'soluciones']}
# {'description': 'Enlace e interlocutor del cliente para entender sus necesidades y garantizar la calidad de los servicios TIC.', 'keywords': ['cliente', 'necesidades']}
# {'description': 'Gestión de los presupuestos, líneas de coste, inversión y facturación con herramientas ERP Fenix y SAP.Gestión de contratación, licitaciones; Gestión de la demanda, supervisión de SLA incidentales y de entrega TIC.', 'keywords': []}
# {'description': 'Gestión de proyectos end-to-end con JIRA y SCRUM, asegurando el cumplimiento de los objetivos estratégicos de la organización.', 'keywords': ['objetivos', 'estrategias']}
# {'description': 'Ejecución del ciclo completo, desde el business case hasta la entrega al cliente, pasando por la gestión de riesgos y costes', 'keywords': ['proceso']}
# {'description': 'Definición de KPI y migración de informes financieros a PowerBI', 'keywords': ['definición']}
# {'description': 'Diseño y aprobación de soluciones de arquitectura de aplicaciones para optimización de rendimiento y costos.', 'keywords': ['arquitectura empresarial']}
# {'description': 'Identificación y análisis de procesos y datos de negocio.', 'keywords': ['análisis', 'información', 'proyectos informáticos']}
# {'description': 'Diseño de dashboards con GRAFANA, sistemas de monitorización como GRAYLOG para optimizar operaciones.', 'keywords': ['diseño']}
# {'description': 'Evaluación de ineficiencias y recomendación de buenas prácticas y comportamiento óptimo del sistema.', 'keywords': ['excelentes', 'enfoques', 'técnicas']}
# {'description': 'Despliegue de stack DevOps con OPENSHIFT y automatización con pipelines CI/CD con JENKINS.', 'keywords': []}
# {'description': 'Desarrollo de soluciones tecnológicas personalizadas, incluyendo aplicaciones web y sistemas de backend en HTML, CSS, JS, PHP, JAVA.', 'keywords': ['desarrollo', 'técnicos']}
# {'description': 'Análisis de requisitos y entrevistas con clientes para definir requisitos y entregar soluciones alineadas con sus objetivos. Definición de la base de datos con ORACLE SQL.', 'keywords': ['analizar', 'captura de requerimientos']}
# {'description': 'dirigiendo un equipo de tres personas. Nuestro objetivo era el desarrollo de software y automatizaciones para el departamento de operaciones. He desarrollado aplicaciones de gestión, herramientas destinadas al mantenimiento de servidores y diversas automatizaciones para la generación de informes.', 'keywords': []}
# assigned: 33 missing 67

# %%
text_adapter_prompt = """You are a professional resume writer and text editor.

**Instructions**:
1. **Preserve meaning** while incorporating all provided **keywords** naturally.
2. **Highlight keywords** in **bold** (e.g., **Python**, **Agile**).
3. **Translate and rewrite** the text **in {language} only**.
4. **Summarize and synthesize** the text to **at most {max_words} words** — keep it concise and impactful.
5. If no keywords are provided, only translate and slightly polish the text in {language}.

Keywords (if any): {keywords}

Output strictly as plain text. Do NOT include explanations or metadata.

/no_think"""

text_adapter_prompt_no_kw = """Return the text in {language}. /no_think"""

class AdaptResponse(BaseModel):
    adapted_text: str = Field(description="Corrected text using all the **keywords**.")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=100, temperature=0.2,  top_p=0.9, top_k=40, repeat_penalty=1.25, seed=42)

def adapt_text(content, keywords, language) -> str:
    """Agente que adapta un texto reescribiendolo con las keywords"""
    try:
        prompt = text_adapter_prompt.format(language=language, max_words=len(content.split())*2, keywords=keywords)
        if keywords is None or len(keywords) == 0:
            prompt = text_adapter_prompt_no_kw.format(language=language)
            
        result = llm.with_structured_output(AdaptResponse).invoke(
            input = [
                SystemMessage(content=prompt),
                HumanMessage(content=content)
            ],
            config = config)    

        return result.adapted_text

    except Exception as e:
        print(f"Error: {e}")
        return content

for i, exp in enumerate(cv_adapted['experiences']):
    for j, text in enumerate(exp['description']):
        new_text = adapt_text(text['description'], text['keywords'] , job_offer.language)
        cv_adapted['experiences'][i]['description'][j].update({'new_description': new_text})
        print(cv_adapted['experiences'][i]['description'][j])
# Out:
# {'description': 'Elaboración de documentación para licitaciones e identificación de requisitos técnicos y funcionales.', 'keywords': ['elaboración', 'licitaciones', 'identificación', 'requisitos'], 'new_description': 'Desarrollo de documentos para **licitaciones** e investigación sobre **requisitos** técnicos y funcionales mediante **identificación** precisa, garantizando cumplimiento normativo en cada etapa del proceso.'}
# {'description': 'Coordinación de equipos técnicos corporativos y seguimiento de proyectos y servicios.', 'keywords': ['proyectos'], 'new_description': 'Coordenación de equipos técnicos corporativos, **seguimiento** de **proyectos** e implementación de servicios.'}
# {'description': 'Facilitar la comunicación con proveedores externos para garantizar la calidad y cumplimiento de acuerdos.', 'keywords': ['comunicación', 'cumplimiento'], 'new_description': 'Fomentar **comunicación** efectiva con proveedores externos, asegurando el **cumplimiento** de estándares y acuerdos.'}
# {'description': 'Impulso de la transformación digital y facilitar la transición a los usuarios hacia nuevas tecnologías.', 'keywords': [], 'new_description': 'Promover la transformación digital e impulsar la transición de los usuarios hacia las nuevas tecnologías.'}
# {'description': 'Gestión de presupuestos y ejecución de proyectos según el Plan estratégico.', 'keywords': ['gestión de proyectos'], 'new_description': 'Administración de presupuesto e implementación de **gestión de proyectos** conforme al plan estrategico.'}
# {'description': 'Evaluación y mitigación de riesgos en servicios y proyectos TIC.', 'keywords': ['gestión de servicios tic'], 'new_description': 'Evaluación y **mitigación** de **riesgos** en **servicios** y **proyectos** TIC.\n\nResumen: Evaluación, gestión de **riesgos**, análisis de impacto y planificación para garantizar la continuidad operativa en servicios y proyectos TIC.'}
# {'description': 'Propuesta y desarrollo de iniciativas de mejora continua.', 'keywords': ['propuestas técnicas', 'mejorar', 'iniciativa'], 'new_description': 'Desarrollo e implementación de **propuestas técnicas** para mejorar procesos mediante **iniciativa**, promoviendo la excelencia operacional en entornos dinámicos.'}
# {'description': 'Gobernanza operativa para la gestión de recursos y despliegue de servicios.', 'keywords': [], 'new_description': 'GOBERNANZA OPERATIVA PARA LA GESTIÓN DE RECURSOS Y DESPLIEGE DE SERVICIOS.'}
# {'description': 'Seguimiento operativo, resolución de incidencias y prevención de obsolescencia tecnológica.', 'keywords': ['precisión', 'proactividad', 'soluciones'], 'new_description': 'Sigo procesos operativos con **precisión**, resuelvo incidentes eficientemente y promuevo la **proactividad** para prevenir la **obsolescencia tecnológica**.'}
# {'description': 'Enlace e interlocutor del cliente para entender sus necesidades y garantizar la calidad de los servicios TIC.', 'keywords': ['cliente', 'necesidades'], 'new_description': 'Conexión con el **cliente** como interlocutor clave, identificando su **necesidades** y asegurando estándares elevados en servicios TIC.'}
# {'description': 'Gestión de los presupuestos, líneas de coste, inversión y facturación con herramientas ERP Fenix y SAP.Gestión de contratación, licitaciones; Gestión de la demanda, supervisión de SLA incidentales y de entrega TIC.', 'keywords': [], 'new_description': 'Gestión del presupuesto, líneas de coste, inversión y facturación con herramientas ERP Fenix y SAP.Gestión de contratación, licitaciones; Gestión de la demanda, supervisión de SLA incidentales y de entrega TIC.'}
# {'description': 'Gestión de proyectos end-to-end con JIRA y SCRUM, asegurando el cumplimiento de los objetivos estratégicos de la organización.', 'keywords': ['objetivos', 'estrategias'], 'new_description': 'Gestión integral de proyectos mediante JIRA y Scrum para garantizar el logro de **objetivos** estratégicos organizacionales. Desarrollo e implementación de **estrategias** efectivas en entornos ágiles.'}
# {'description': 'Ejecución del ciclo completo, desde el business case hasta la entrega al cliente, pasando por la gestión de riesgos y costes', 'keywords': ['proceso'], 'new_description': 'Gestión integral del proceso, desde el desarrollo inicial hasta su implementación final. Incluye análisis de riesgos, control presupuestario y aseguramiento de cumplimiento en cada etapa.'}
# {'description': 'Definición de KPI y migración de informes financieros a PowerBI', 'keywords': ['definición'], 'new_description': 'La **definición** del término KPI es clave para medir el éxito en proyectos. Además, la **migración** de los reportes financieros hacia un sistema como **Power BI** permite una mejor toma de decisiones basada en datos reales y actualizados.'}
# {'description': 'Diseño y aprobación de soluciones de arquitectura de aplicaciones para optimización de rendimiento y costos.', 'keywords': ['arquitectura empresarial'], 'new_description': 'Disenyo y aprobacion de soluciones de **arquitectura empresarial** para optimizacion del rendimiento y los costos.'}
# {'description': 'Identificación y análisis de procesos y datos de negocio.', 'keywords': ['análisis', 'información', 'proyectos informáticos'], 'new_description': 'Identificación y **análisis** de procesos y datos de negocio para optimizar la toma de decisiones basada en **información** precisa e integrar soluciones tecnológicas a través de proyectos informáticos orientados al desarrollo sostenible. '}
# {'description': 'Diseño de dashboards con GRAFANA, sistemas de monitorización como GRAYLOG para optimizar operaciones.', 'keywords': ['diseño'], 'new_description': 'Diseño y desarrollo de **dashboards** en **GRAFANA**, integración con herramientas de **monitorización** como **GRAYLOG** para mejorar la eficiencia operativa.'}
# {'description': 'Evaluación de ineficiencias y recomendación de buenas prácticas y comportamiento óptimo del sistema.', 'keywords': ['excelentes', 'enfoques', 'técnicas'], 'new_description': 'Análisis de desempeño para identificar ineficiencias, proponer mejores prácticas y optimizar el comportamiento del sistema con enfoques técnicas excelentes.'}
# {'description': 'Despliegue de stack DevOps con OPENSHIFT y automatización con pipelines CI/CD con JENKINS.', 'keywords': [], 'new_description': 'Implementación del Stack DevOps con OpenShift y automatización mediante pipelines CI/CD con Jenkins.'}
# {'description': 'Desarrollo de soluciones tecnológicas personalizadas, incluyendo aplicaciones web y sistemas de backend en HTML, CSS, JS, PHP, JAVA.', 'keywords': ['desarrollo', 'técnicos'], 'new_description': 'Diseño e implementación de **desarrollo** técnico para proyectos empresariales mediante herramientas como HTML, CSS, JavaScript, Java y PHP; desarrollo de soluciones escalables con énfasis en arquitectura backend.'}
# {'description': 'Análisis de requisitos y entrevistas con clientes para definir requisitos y entregar soluciones alineadas con sus objetivos. Definición de la base de datos con ORACLE SQL.', 'keywords': ['analizar', 'captura de requerimientos'], 'new_description': 'Realizo **análisis** de requerimientos mediante **captura de requerimientos**, entrevistas a clientes para definir necesidades y entregar soluciones alineadas con sus objetivos. Diseño e implementación de la base de datos utilizando ORACLE SQL.'}
# {'description': 'dirigiendo un equipo de tres personas. Nuestro objetivo era el desarrollo de software y automatizaciones para el departamento de operaciones. He desarrollado aplicaciones de gestión, herramientas destinadas al mantenimiento de servidores y diversas automatizaciones para la generación de informes.', 'keywords': [], 'new_description': 'Dirigiendo un equipo de tres personas. Nuestro objetivo era el desarrollo de software y automatizaciones para el departamento de operaciones. He desarrollado aplicaciones de gestión, herramientas destinadas al mantenimiento de servidores y diversas automatizaciones para la generación de informes.'}

# %%
def match_skills_loop(skills_list, keywords_list):

    skill_extractor_prompt = """
    You are a semantic matcher specialized in computer science and project management terminology.

    Given a list of technical terms (keywords_list) and ONE target_term, your task is to select the one and most semantically equivalent or closely related term from the list.

    IMPORTANT: You MUST ONLY respond with a term that BEST matches one of the keywords in the keywords_list. Do not invent new terms, do not modify existing terms, and do not return the target_term itself if it's not in the keywords_list.

    If none of the provided keywords accurately match the meaning of the input term within this domain, respond 'None'.

    Context:
    - Domain: Computer Science & Project Management
    - keywords_list: {keywords}

    Respond ONLY with the best matching keyword from the list, or 'None' if no match is found.
    /no_think"""

    config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

    llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=100, temperature=0.1,  top_p=0.0, top_k=10, repeat_penalty=1.1, seed=42)

    class Response(BaseModel):
        equivalent: str = Field(description="most semantically equivalent or closely related term")

    def find_skill_match(skill, keywords):

        match = None
        try:
            match = llm.with_structured_output(Response).invoke(
                input = [
                    SystemMessage(content=skill_extractor_prompt.format(keywords=keywords)),
                    HumanMessage(content='target_term: '+skill)
                ],
                config = config).equivalent

        except Exception as e:
            print(e)

        return match

    extracted_skills = []

    for skill in skills_list:
        match =  find_skill_match(skill, keywords_list)
        extracted_skill = {'origen': skill, 'coincidencia': match}
        extracted_skills.append(extracted_skill)

    return extracted_skills


skills_list = cv_adapted['soft_skills'] + base_skills_list 
print(skills_list)
print('-'*100)
print(keywords_list)
print('-'*100)

relaciones = match_skills_loop(skills_list, keywords_list)
display(relaciones)
# Out:
# ['Liderazgo', 'Negociación', 'Visión estratégica', 'Orientación a objetivos', 'Escucha activa', 'Mejora continua', 'Pensamiento analítico', 'Solución de problemas', 'Retroactividad y autonomía', 'Soluciones técnicas', 'Iniciativa', 'Orientación al logro', 'Planificación y organización', 'Preocupación por el orden y la calidad', 'Dirección de personas', 'Liderazgo', 'Trabajo en equipo y cooperación', 'Autoconfianza', 'Autocontrol', 'Compromiso con la organización', 'Flexibilidad y gestión del cambio', 'Comunicación', 'Empatía', 'Negociación', 'Networking', 'Orientación al cliente', 'Aprendizaje y utilización de conocimientos', 'Creatividad', 'Orientación estratégica', 'Pensamiento analítico', 'Pensamiento conceptual']
# ----------------------------------------------------------------------------------------------------
# ['aca', 'administración', 'agile', 'ambigüedades', 'análisis funcionales', 'appian', 'archi', 'autonomía', 'bpm', 'capacidad resolutiva', 'castellano', 'catalunya', 'catalán', 'chatgpt', 'claridad', 'colaborar', 'colaborativa', 'comerciales', 'componentes', 'conocimientos', 'copilot 360', 'ctti', 'diagramas entidad-relación', 'documentación', 'draw.io', 'dual track', 'electrónica', 'equipos multidisciplinarios', 'escrita', 'estandarizada', 'excel', 'experiencia', 'gemini', 'grupo', 'habilidades', 'imi', 'inconsistencias', 'informáticas', 'informáticos', 'inteligencia artificial', 'it4it', 'itil', 'kanban', 'lean', 'low code', 'microsoft', 'modelaje de dominios funcionales', 'outsystems', 'participar', 'planner', 'plantillas', 'powerplatform', 'powerpoint', 'principales', 'propuestas', 'redacción', 'redactar', 'regional', 'revisar', 'scrum', 'secdevops', 'sharepoint', 'uml', 'visio', 'word', 'workflows', 'ámbito']
# ----------------------------------------------------------------------------------------------------
# [{'origen': 'Liderazgo', 'coincidencia': 'colaborativa'},
#  {'origen': 'Negociación', 'coincidencia': 'colaborativa'},
#  {'origen': 'Visión estratégica', 'coincidencia': 'propuestas'},
#  {'origen': 'Orientación a objetivos', 'coincidencia': 'colaborativa'},
#  {'origen': 'Escucha activa', 'coincidencia': 'colaborativa'},
#  {'origen': 'Mejora continua', 'coincidencia': 'agile'},
#  {'origen': 'Pensamiento analítico', 'coincidencia': 'capacidad resolutiva'},
#  {'origen': 'Solución de problemas', 'coincidencia': 'capacidad resolutiva'},
#  {'origen': 'Retroactividad y autonomía', 'coincidencia': 'autonomía'},
#  {'origen': 'Soluciones técnicas', 'coincidencia': 'propuestas'},
#  {'origen': 'Iniciativa', 'coincidencia': 'propuestas'},
#  {'origen': 'Orientación al logro', 'coincidencia': 'autonomía'},
#  {'origen': 'Planificación y organización', 'coincidencia': 'planner'},
#  {'origen': 'Preocupación por el orden y la calidad',
#   'coincidencia': 'estandarizada'},
#  {'origen': 'Dirección de personas', 'coincidencia': 'autonomía'},
#  {'origen': 'Liderazgo', 'coincidencia': 'autonomía'},
#  {'origen': 'Trabajo en equipo y cooperación', 'coincidencia': 'colaborar'},
#  {'origen': 'Autoconfianza', 'coincidencia': 'autonomía'},
#  {'origen': 'Autocontrol', 'coincidencia': 'autonomía'},
#  {'origen': 'Compromiso con la organización', 'coincidencia': 'colaborativa'},
#  {'origen': 'Flexibilidad y gestión del cambio', 'coincidencia': 'agile'},
#  {'origen': 'Comunicación', 'coincidencia': 'colaborativa'},
#  {'origen': 'Empatía', 'coincidencia': 'colaborativa'},
#  {'origen': 'Negociación', 'coincidencia': 'colaborativa'},
#  {'origen': 'Networking', 'coincidencia': 'redes'},
#  {'origen': 'Orientación al cliente', 'coincidencia': 'colaborativa'},
#  {'origen': 'Aprendizaje y utilización de conocimientos',
#   'coincidencia': 'conocimientos'},
#  {'origen': 'Creatividad', 'coincidencia': 'autonomía'},
#  {'origen': 'Orientación estratégica', 'coincidencia': 'propuestas'},
#  {'origen': 'Pensamiento analítico', 'coincidencia': 'capacidad resolutiva'},
#  {'origen': 'Pensamiento conceptual', 'coincidencia': 'conocimientos'}]

# %%
def match_skills_bulk(skills_list, keywords_list):
    """
    Utiliza un LLM local vía Ollama para encontrar relaciones semánticas
    entre dos listas de términos.
    """
    
    # Construimos el prompt instruyendo al modelo claramente
    prompt = f"""
    Eres un experto en semántica y lingüística. Tu tarea es relacionar cada término de la 'Lista A' con su equivalente significativo en la 'Lista B'.
    Los términos pueden estar expresados de forma diferente (sinónimos, jerga, descripciones), pero deben coincidir en significado.
    
    Reglas:
    1. Cada término de la Lista A debe tener máximo una coincidencia en la Lista B.
    2. Si un término de la Lista A no tiene relación con nada en la Lista B, asigna null al valor correspondiente.
    3. Devuelve ÚNICAMENTE un objeto JSON válido. No incluyas texto explicativo antes ni después.
    4. El formato JSON debe ser una lista de objetos: [{{"origen": "term_a", "coincidencia": "term_b"}}, ...]

    Lista A: {skills_list}
    Lista B: {keywords_list}

    Responde solo con el JSON:
    """

    config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

    llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=1024, temperature=0.1,  top_p=0.5, top_k=40, repeat_penalty=1.1, seed=42)


    class MatchResponse(BaseModel):
        origen: str = Field(description="term_a")
        coincidencia: str = Field(description="term_b")

    class ListResponse(BaseModel):
        listitems: List[MatchResponse] = Field(description="lista de equivalencias")

    try:
        # Llamada a Ollama local
        return llm.with_structured_output(ListResponse).invoke(
            input = [
                # SystemMessage(content=skill_extractor_prompt.format(keywords=keywords)),
                HumanMessage(content=prompt)
            ],
            config = config)
        
    except Exception as e:
        print(e)
        return None


skills_list = cv_adapted['soft_skills'] #+ base_skills_list 
print(skills_list)
print('-'*100)
print(keywords_list)
print('-'*100)

relaciones = match_skills_bulk(skills_list, keywords_list)
relaciones = [i.model_dump() for i in relaciones.listitems]
display(relaciones)
# Out:
# ['Liderazgo', 'Negociación', 'Visión estratégica', 'Orientación a objetivos', 'Escucha activa', 'Mejora continua', 'Pensamiento analítico', 'Solución de problemas', 'Retroactividad y autonomía', 'Soluciones técnicas']
# ----------------------------------------------------------------------------------------------------
# ['aca', 'administración', 'agile', 'ambigüedades', 'análisis funcionales', 'appian', 'archi', 'autonomía', 'bpm', 'capacidad resolutiva', 'castellano', 'catalunya', 'catalán', 'chatgpt', 'claridad', 'colaborar', 'colaborativa', 'comerciales', 'componentes', 'conocimientos', 'copilot 360', 'ctti', 'diagramas entidad-relación', 'documentación', 'draw.io', 'dual track', 'electrónica', 'equipos multidisciplinarios', 'escrita', 'estandarizada', 'excel', 'experiencia', 'gemini', 'grupo', 'habilidades', 'imi', 'inconsistencias', 'informáticas', 'informáticos', 'inteligencia artificial', 'it4it', 'itil', 'kanban', 'lean', 'low code', 'microsoft', 'modelaje de dominios funcionales', 'outsystems', 'participar', 'planner', 'plantillas', 'powerplatform', 'powerpoint', 'principales', 'propuestas', 'redacción', 'redactar', 'regional', 'revisar', 'scrum', 'secdevops', 'sharepoint', 'uml', 'visio', 'word', 'workflows', 'ámbito']
# ----------------------------------------------------------------------------------------------------
# [{'origen': 'Liderazgo', 'coincidencia': 'colaborativa'},
#  {'origen': 'Negociación', 'coincidencia': 'negociar'},
#  {'origen': 'Visión estratégica', 'coincidencia': 'estratégico'},
#  {'origen': 'Orientación a objetivos', 'coincidencia': 'objetivos'},
#  {'origen': 'Escucha activa', 'coincidencia': 'escucha'},
#  {'origen': 'Mejora continua', 'coincidencia': 'continua'},
#  {'origen': 'Pensamiento analítico', 'coincidencia': 'análisis funcionales'},
#  {'origen': 'Solución de problemas', 'coincidencia': 'capacidad resolutiva'},
#  {'origen': 'Retroactividad y autonomía', 'coincidencia': 'autonomía'},
#  {'origen': 'Soluciones técnicas', 'coincidencia': 'soluciones'}]

# %%
text_adapter_prompt = """You are a professional resume writer and text editor.

You have to express '{soft_skill}' in a way that contains '{keywords}'.

**Instructions**:
1. **Preserve meaning** while incorporating all provided **keywords** naturally.
2. Be concise, do not explain. do not elavorate.
3. **Translate and rewrite** the text **in {language} only**.
4. **Summarize and synthesize** the text to **at most {max_words} words** — keep it concise and impactful.
5. If no keywords are provided, only translate and slightly polish the text in {language}.

Output strictly as plain text. Do NOT include explanations or metadata.

/no_think"""

class AdaptResponse(BaseModel):
    adapted_text: str = Field(description="The final rewritten resume bullet point.")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=100, temperature=0.2,  top_p=0.9, top_k=40, repeat_penalty=1.1, seed=42)

def adapt_soft_skill(content, keywords, language) -> str:
    """Agente que adapta un texto reescribiendolo con las keywords"""
    try:
        prompt = text_adapter_prompt.format(soft_skill=content, language=language, max_words=len(content.split())*2, keywords=keywords)
            
        result = llm.with_structured_output(AdaptResponse).invoke(
            input = [
                SystemMessage(content=prompt),
                HumanMessage(content=content)
            ],
            config = config)    

        return result.adapted_text

    except Exception as e:
        print(f"Error: {e}")
        return content

for text in relaciones:
    text['new_text'] = adapt_soft_skill(text['origen'], text['coincidencia'] , job_offer.language)
    display(text)
# Out:
# {'origen': 'Liderazgo',
#  'coincidencia': 'colaborativa',
#  'new_text': 'Liderazgo colaborativo'}
# {'origen': 'Negociación', 'coincidencia': 'negociar', 'new_text': 'negociar'}
# {'origen': 'Visión estratégica',
#  'coincidencia': 'estratégico',
#  'new_text': 'Visión estratégico'}
# {'origen': 'Orientación a objetivos',
#  'coincidencia': 'objetivos',
#  'new_text': 'Enfoque en metas y objetivos'}
# {'origen': 'Escucha activa',
#  'coincidencia': 'escucha',
#  'new_text': 'Escucha activa'}
# {'origen': 'Mejora continua',
#  'coincidencia': 'continua',
#  'new_text': 'Mejora continua'}
# {'origen': 'Pensamiento analítico',
#  'coincidencia': 'análisis funcionales',
#  'new_text': 'Pensamiento analítico con análisis funcionales'}
# {'origen': 'Solución de problemas',
#  'coincidencia': 'capacidad resolutiva',
#  'new_text': 'Capacidad resolutiva para resolver problemas'}
# {'origen': 'Retroactividad y autonomía',
#  'coincidencia': 'autonomía',
#  'new_text': 'Autonomía y retroactividad'}
# {'origen': 'Soluciones técnicas',
#  'coincidencia': 'soluciones',
#  'new_text': 'Soluciones técnicas'}

# %%
import base64

def encode_base64(data):
    if isinstance(data, str):
        data = data.encode('utf-8')
    
    encoded = base64.b64encode(data)
    return encoded.decode('utf-8')

def decode_base64(encoded_data):
    decoded = base64.b64decode(encoded_data.encode('utf-8'))
    return decoded.decode('utf-8')

# Test encoding
original_text = """secret"""
encoded = encode_base64(original_text)
print(f"Original: {original_text}")
print(f"Encoded:  {encoded}")

# Test decoding
decoded = decode_base64(encoded)
print(f"Decoded:  {decoded}")
# Out:
# Original: secret
# Encoded:  c2VjcmV0
# Decoded:  secret

# %%
from jinja2 import Environment, FileSystemLoader
import re

def render_cv(cv_data):

    # Create environment and load template
    env = Environment(loader=FileSystemLoader('./data/'))
    template = env.get_template('cv_template_es.html')

    cv_data['contact_info'] = decode_base64(cv_data['contact_info'])
    cv_data['name'] = decode_base64(cv_data['name'])

    for e in range(0, len(cv_data['experiences'])):
        for t in range(0, len(cv_data['experiences'][e]['description'])):
            cv_data['experiences'][e]['description'][t] = re.sub(r'\*\*(.*?)\*\*', r'<strong>\1</strong>', cv_data['experiences'][e]['description'][t])

    # Render template with model
    output = template.render(cv_data)

    # Print or save output
    with open(cv_filepath(job_offer_url), "w") as f:
        f.write(output)

render_cv(dict(cv_adapted))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 24
#      21     with open(cv_filepath(job_offer_url), "w") as f:
#      22         f.write(output)
# ---> 24 render_cv(dict(cv_adapted))
#
# Cell In[37], line 15, in render_cv(cv_data)
#      13 for e in range(0, len(cv_data['experiences'])):
#      14     for t in range(0, len(cv_data['experiences'][e]['description'])):
# ---> 15         cv_data['experiences'][e]['description'][t] = re.sub(r'\*\*(.*?)\*\*', r'<strong>\1</strong>', cv_data['experiences'][e]['description'][t])
#      17 # Render template with model
#      18 output = template.render(cv_data)
#
# File /usr/lib/python3.13/re/__init__.py:208, in sub(pattern, repl, string, count, flags, *args)
#     202     import warnings
#     203     warnings.warn(
#     204         "'count' is passed as positional argument",
#     205         DeprecationWarning, stacklevel=2
#     206     )
# --> 208 return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'dict'

# %%
# Save html file to pdf
import pdfkit

def convert_html_to_pdf(html_path, pdf_path):
    html_content = open(html_path).read()
    pdfkit.from_string(html_content, pdf_path)
    print(f"PDF saved at {pdf_path}")


convert_html_to_pdf(cv_filepath(job_offer_url), pdf_filepath(job_offer_url))

# %%
import shutil
cv_original_odt = 'workspace/curr/cv_original.odt'
cv_adapted_odt = 'workspace/curr/cv_adapted.odt'
try:
    shutil.copy2(cv_original_odt, cv_adapted_odt)
except:
    pass

# %%
import zipfile
import xml.etree.ElementTree as ET
from IPython.display import Markdown, display

def get_odt_root(file_path):
    with zipfile.ZipFile(file_path, 'r') as z:
        with z.open("content.xml") as f:
            tree = ET.parse(f)
            return tree.getroot()

def extraer_texto_odf(file_path):
    """
    Extrae todo el texto plano de un archivo ODF.
    Soporta .odt, .ods y otros formatos ODF.
    """
    texto_completo = []

    def text_with_links(elem):
        """Genera texto incluyendo enlaces en formato Markdown [texto](href)."""
        result = []
        for child in elem:
            tag_local = child.tag.split("}")[-1]
            if tag_local == "a":
                href = child.attrib.get("{http://www.w3.org/1999/xlink}href", "")
                texto_link = "".join(child.itertext()).strip()
                result.append(f"[{texto_link}]({href})")
            else:
                result.append(text_with_links(child) if child is not None else child.text or "")
        if elem.text:
            result.insert(0, elem.text)
        return "".join(result)

    root = get_odt_root(file_path)

    elem_id = 0
    for elem in root.iter():
        tag_local = elem.tag.split("}")[-1]
        if tag_local in ("p", "h"):
            texto = text_with_links(elem).strip()
            if texto:
                if tag_local == "h":
                    # Obtener nivel del encabezado (por defecto 1 si no hay atributo)
                    nivel = int(elem.get("{urn:oasis:names:tc:opendocument:xmlns:text:1.0}outline-level", "1"))
                    nivel = max(1, min(nivel, 6))  # Limitar entre 1 y 6 (Markdown estándar)
                    texto = f"\n---\n{'#' * nivel} {texto} []({elem_id})\n"
                elif texto[0] not in ['-']:
                    texto = f"- {texto} []({elem_id})"
                texto_completo.append(texto)
        elem_id += 1

    return "\n".join(texto_completo)

cv_content = extraer_texto_odf(cv_adapted_odt)
# display(Markdown(cv_content))
print(cv_content[-600:])
# Out:
#  sistemas de backend en HTML, CSS, JS, PHP, JAVA. [](216)
# - Análisis de requisitos y entrevistas con clientes para definir requisitos y entregar soluciones alineadas con sus objetivos. Definición de la base de datos con ORACLE SQL. [](217)
#
# ---
# ### Development Team Lead en T-Systems [](219)
#
# - Dirigiendo un equipo de tres personas. Nuestro objetivo era el desarrollo de software y automatizaciones para el departamento de operaciones. He desarrollado aplicaciones de gestión, herramientas destinadas al mantenimiento de servidores y diversas automatizaciones para la generación de informes. [](221)

# %%
def modificar_texto_odf(file_path, elem_id, texto):
    """
    Modifica el texto de un elemento específico en un archivo ODF (.odt) basado en su ID de iteración.
    """
    import zipfile
    import xml.etree.ElementTree as ET
    import os
    import shutil
    import tempfile

    # Crear una copia temporal para trabajar de forma segura
    temp_dir = tempfile.mkdtemp()
    temp_zip_path = os.path.join(temp_dir, "temp.odt")
    
    try:
        # Copiar el archivo original al temporal
        shutil.copy(file_path, temp_zip_path)

        root = get_odt_root(temp_zip_path)

        # Buscar el elemento
        elem_id_actual = 0
        elemento_encontrado = None
        
        for elem in root.iter():
            tag_local = elem.tag.split("}")[-1]
            if tag_local in ("p", "h"):
                if elem_id_actual == elem_id:
                    elemento_encontrado = elem
                    break
            elem_id_actual += 1

        if elemento_encontrado is None:
            raise ValueError(f"No se encontró ningún elemento con elem_id = {elem_id}.")

        # Modificar contenido
        # elemento_encontrado.clear()
        elemento_encontrado.text = texto

        # Convertir árbol modificado a bytes
        xml_str = ET.tostring(root, encoding='utf-8', xml_declaration=True)

        # 2. Escribir el nuevo archivo .odt
        with zipfile.ZipFile(file_path, 'w', compression=zipfile.ZIP_DEFLATED) as z_out:
            with zipfile.ZipFile(temp_zip_path, 'r') as z_in:
                for item in z_in.infolist():
                    if item.filename == "content.xml":
                        continue # Se escribe manualmente abajo
                    data = z_in.read(item.filename)
                    z_out.writestr(item, data)
            
            # Escribir el content.xml modificado
            z_out.writestr("content.xml", xml_str)

        print(f"Archivo '{file_path}' actualizado correctamente en el elemento ID {elem_id}.")
    except Exception as e:
        print(e)
    finally:
        # Limpieza del directorio temporal
        if os.path.exists(temp_dir):
            shutil.rmtree(temp_dir, ignore_errors=True)


modificar_texto_odf(file_path=cv_adapted_odt, elem_id=221, texto="Experto en Python y Django")
cv_content = extraer_texto_odf(cv_adapted_odt)
# display(Markdown(cv_content))
print(cv_content[-600:])
# Out:
# Archivo 'workspace/curr/cv_adapted.odt' actualizado correctamente en el elemento ID 221.
# rrollo con SCRUM; validación de documentos de arquitectura, asegurando el cumplimiento de estándares. [](213)
#
# ---
# ### Analista funcional en ITNow (SII Concatel) (2013 +3 anys) [](215)
#
# - Desarrollo de soluciones tecnológicas personalizadas, incluyendo aplicaciones web y sistemas de backend en HTML, CSS, JS, PHP, JAVA. [](216)
# - Análisis de requisitos y entrevistas con clientes para definir requisitos y entregar soluciones alineadas con sus objetivos. Definición de la base de datos con ORACLE SQL. [](217)
#
# ---
# ### Development Team Lead en T-Systems [](219)
#
# - Experto en Python y Django [](221)
