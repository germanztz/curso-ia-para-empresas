# %%
from langchain_ollama import ChatOllama
import json
import re

# TODO
# Usar idioma de la oferta -- OK
# Afinar y aprobar en una segunda pasada la job description para evitar repeticiones, concatenaciones de keywords sin sentido
# traducir titulos de curriculum
# Extraer soft skills generales (evitar usarlas en las job description?)
# usar modelo qwen3:32b 
# optimizar tags html en template
# leer curriculum original para escrapear los datos
# generar pdf
# generar documento editable word? odf? para corregir

cv_file_path = 'data/cv_data_es.json'
soft_skill_file_path = 'data/soft_skill_es.json'
cv_data = {}
soft_skill = {}

wpd_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.document.wpd"
cva_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv_adapted.json"
cv_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.html"
pdf_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.pdf"

# Load JSON file into a dictionary
with open(cv_file_path, 'r') as f:
    cv_data = json.load(f)
with open(soft_skill_file_path, 'r') as f:
    soft_skill = json.load(f)

# with open(soft_skill_file_path, "w") as json_file:
#     json.dump(soft_skill_es, json_file, indent=4)

use_cache=True

llm_strong = ChatOllama(model='qwen3:32b', reasoning=False)
llm_ligth = ChatOllama(model='qwen3:14b', reasoning=False)

job_offer_url = 'https://www.linkedin.com/jobs/view/4362181901'
# job_offer_url = 'https://www.linkedin.com/jobs/view/4317166787'
# job_offer_url = 'https://selection.uoc.edu/web/offersjob/offerdetails.aspx?offerID=5464EA521BB0E0207C9DA853CA6F8505F72B82E3D56D2CAD90882623EBEE1FA7'

# %%
from tools import web_operations
import pickle
from langchain_core.documents import Document
import re
import os

def load_document(url, use_cache=True):

    document = None
    job_offer_file_path = wpd_filepath(url)
    if os.path.exists(job_offer_file_path) and use_cache:
        with open(job_offer_file_path, "rb") as f:
            document = pickle.load(f)
            print("loaded from cache file", job_offer_file_path)
    else:
        document = web_operations.scrape_webpages.invoke(input={'url':url, 'include_links':False })[0]
        with open(job_offer_file_path, "wb") as f:
            pickle.dump(document, f)
        print("loaded from url")
        
    return document

document = load_document(job_offer_url, use_cache=use_cache)
print(document.metadata['title'])
# Out:
# loaded from cache file workspace/https_www_linkedin_com_jobs_view_4362181901.document.wpd
# DXC Technology hiring Analista técnico/funcional informático/a in Sant Cugat del Vallès, Catalonia, Spain | LinkedIn

# %%
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langchain_ollama import ChatOllama
from langfuse.langchain import CallbackHandler

def summarize_text_llm(text: str, 
    llm_model = llm_ligth,
    llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]},
    system_prompt = "Summarize the given text in 100 words /no_think",
    response_format=None,
    name="summarization_agent",
    ) -> str :

    summarization_agent = create_agent(name=name, model=llm_model, system_prompt=system_prompt, response_format=response_format )
    return summarization_agent.invoke({"messages": [("user", text)]}, config=llm_config)

# %%
from typing import Annotated, List, Dict, Any, Optional
from langchain_core.documents import Document
from typing import TypedDict, Literal
from pathlib import Path
from pydantic import BaseModel, Field

def job_parts(doc: Document, use_cache: bool = True):
    # Cache check — use .get() to avoid KeyError
    if use_cache and all(key in doc.metadata for key in ['job_position_title']):
        return 

    class JobOffer(BaseModel):
        language: Literal['Spanish', 'Catalan', 'English'] = Field(description="The detected language")
        job_position_title: str = Field(description="Job title with correct gender form")
        company_description: str = Field(description="Concise, jargon-free company summary")
        job_functions: list[str] = Field(description="Verbatim job responsibilities")
        job_requirements: list[str] = Field(description="Verbatim formal requirements")

    # Prompt template
    job_analyzer_prompt = """You are a precise job offer analyzer. 
Extract and structure the information strictly according to the schema:
- Use only `{gender}` form for the job title.
- Preserve original wording and language for functions and requirements.
- Keep company description clear, human-friendly, and jargon-free.
/no_think"""

    try:
        response = summarize_text_llm(
            text=f"# {doc.metadata.get('title', 'Untitled Job Offer')}\n{doc.page_content}",
            name='job_analyzer',
            llm_model=llm_strong,
            system_prompt=job_analyzer_prompt.format(gender=cv_data['gender']),
            response_format=ToolStrategy(JobOffer)
        )

        job_offer = response['structured_response'].model_dump()

        doc.metadata.update(job_offer)

        # Save to cache (pickle) — robustly
        source_path = doc.metadata.get('source', 'unknown')
        wpd_path = Path(wpd_filepath(source_path))
        wpd_path.parent.mkdir(parents=True, exist_ok=True)  # ensure dir exists
        with open(wpd_path, 'wb') as f:
            pickle.dump(doc, f)

    except KeyError as e:
        print(f"❌ Missing expected key in response: {e}")
        raise
    except Exception as e:
        print(f"⚠️ Job parts processing failed for: {doc.metadata.get('source', 'unknown')}")
        print(f"Error: {e}")
        raise

job_parts(document, use_cache)
display(document.metadata)
# Out:
# {'source': 'https://www.linkedin.com/jobs/view/4362181901',
#  'title': 'DXC Technology hiring Analista técnico/funcional informático/a in Sant Cugat del Vallès, Catalonia, Spain | LinkedIn',
#  'description': 'Posted 12:16:42 AM. Job DescriptionJob DescriptionDXC Technology es una compañía global de servicios profesionales cuya…See this and similar jobs on LinkedIn.',
#  'language': 'Spanish',
#  'job_position_title': 'Analista técnico/funcional informático',
#  'company_description': 'DXC Technology es una compañía global de servicios profesionales dedicada a liderar la transformación digital de sus clientes. Con más de 130.000 empleados en 70 países, ofrece soluciones avanzadas de TI. En España, cuenta con cerca de 8.000 profesionales distribuidos en trece ubicaciones, sirviendo a más de 200 clientes de los sectores público y privado con centros de excelencia en tecnologías como Cloud, Inteligencia de Negocio e IA.',
#  'job_functions': [{'title': 'Análisis de requisitos y diseño de soluciones informáticas. Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos.',
#    'keywords': ['requisitos',
#     'diseño',
#     'soluciones informáticas',
#     'incompatibilidades',
#     'ambigüedades',
#     'inconsistencias'],
#    'id': 0},
#   {'title': 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos.',
#    'keywords': ['equipos multidisciplinarios',
#     'propuestas técnicas',
#     'propuestas comerciales',
#     'licitaciones',
#     'proyectos informáticos',
#     'requisitos'],
#    'id': 1},
#   {'title': 'Desarrollar y mantener plantillas y documentación estandarizada para agilizar el proceso de redacción.',
#    'keywords': ['Desarrollar',
#     'mantener',
#     'plantillas',
#     'documentación',
#     'estandarizada',
#     'agilizar',
#     'proceso'],
#    'id': 2},
#   {'title': 'Participar en la definición de estrategias y enfoques para licitaciones, considerando las necesidades del cliente y los objetivos comerciales.',
#    'keywords': ['estrategias', 'licitaciones', 'cliente', 'objetivos'],
#    'id': 3},
#   {'title': 'Recopilar y analizar información relativa a licitaciones previas al objeto de mejorar las futuras propuestas a realizar.',
#    'keywords': ['licitaciones', 'propuestas', 'análisis', 'información'],
#    'id': 4}],
#  'job_requirements': [{'title': 'Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI).',
#    'keywords': ['propuestas técnicas',
#     'propuestas comerciales',
#     'licitaciones',
#     'desarrollo de proyectos informáticos',
#     'CTTI'],
#    'id': 5},
#   {'title': 'Experiencia en la realización de análisis funcionales y captura de requerimientos.',
#    'keywords': ['análisis funcionales', 'captura de requerimientos'],
#    'id': 6},
#   {'title': 'Conocimientos técnicos sobre los principales componentes de administración electrónica del ámbito regional de Catalunya (CTTI, IMI, ACA, etc.).',
#    'keywords': ['administración electrónica',
#     'CTTI',
#     'IMI',
#     'ACA',
#     'Catalunya'],
#    'id': 7},
#   {'title': 'Deseable disponer de conocimientos técnicos sobre arquitecturas Low Code (Outsystems, Appian, PowerPlatform).',
#    'keywords': ['Low Code',
#     'Outsystems',
#     'Appian',
#     'PowerPlatform',
#     'arquitecturas'],
#    'id': 8},
#   {'title': 'Familiarizado con el uso de herramientas gráficas de modelaje de Arquitectura Empresarial (Archi, Visio, Draw.io o similares) y de modelaje de dominios funcionales (UML, Diagramas Entidad-Relación, Workflows, BPM, etc.).',
#    'keywords': ['Archi',
#     'Visio',
#     'Draw.io',
#     'UML',
#     'Diagramas Entidad-Relación',
#     'Workflows',
#     'BPM',
#     'Arquitectura Empresarial',
#     'modelaje'],
#    'id': 9},
#   {'title': 'Conocimientos en metodologías Gestión de Proyectos Lean/Agile (Scrum, Kanban, Dual Track, etc).',
#    'keywords': ['Gestión de Proyectos',
#     'Lean',
#     'Agile',
#     'Scrum',
#     'Kanban',
#     'Dual Track'],
#    'id': 10},
#   {'title': 'Conocimiento en metodologías de Gestión de Servicios TIC (ITIL, IT4IT, SecDevOps, etc.).',
#    'keywords': ['ITIL', 'IT4IT', 'SecDevOps', 'Gestión de Servicios TIC'],
#    'id': 11},
#   {'title': 'Experiencia utilizando herramientas de productividad de Microsoft (Word, Excel, PowerPoint, SharePoint, Planner, etc.) e Inteligencia Artificial (ChatGPT, Copilot 360, Gemini o similares) para automatizar y mejorar ciertos procesos de redacción de las ofertas.',
#    'keywords': ['Microsoft',
#     'Word',
#     'Excel',
#     'PowerPoint',
#     'SharePoint',
#     'Planner',
#     'Inteligencia Artificial',
#     'ChatGPT',
#     'Copilot 360',
#     'Gemini',
#     'Automatizar',
#     'Procesos',
#     'Redacción',
#     'Ofertas'],
#    'id': 12},
#   {'title': 'Excelentes habilidades de comunicación (especialmente escrita) en castellano y catalán.',
#    'keywords': ['comunicación', 'castellano', 'catalán'],
#    'id': 13},
#   {'title': 'Habituado a trabajar en grupo de forma colaborativa.',
#    'keywords': ['trabajo en grupo', 'colaborativo'],
#    'id': 14},
#   {'title': 'Capacidad resolutiva, proactividad, iniciativa y autonomía.',
#    'keywords': ['Capacidad resolutiva',
#     'proactividad',
#     'iniciativa',
#     'autonomía'],
#    'id': 15}]}

# %%
# class Keyword(TypedDict):
#     word: str
#     category: Literal['technology_name','soft_skill','organization_name']

class Keywords(TypedDict):
    keywords: list[str]

def extract_keywords(item, use_cache = True):
    keywords = item['keywords'] if type(item) is dict else []
    item = item['title'] if type(item) is dict else item

    keyword_extractor_prompt = """Extract the keywords in the field of computer science and project management.
Keep the keywords short and simple.
Stick to the text, Do not invent new words.
/no_think"""

    if len(keywords) > 0 and use_cache:
        return {'title':item, 'keywords': keywords}
    try:
        response = summarize_text_llm(text=item, name='keyword_extractor', llm_model = llm_ligth,
        llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]},
        response_format=ToolStrategy(Keywords),  system_prompt = keyword_extractor_prompt, )

        keywords = response['structured_response']['keywords']
    except Exception as e:
        print(e)
    return {'title':item, 'keywords': keywords}
  
# extract_keywords(document.metadata['job_requirements'][0])

# %%
def extract_document_keywords(doc: Document, use_cache = True):

    id = 0

    for f in range(0,len(doc.metadata['job_functions'])):
        item = doc.metadata['job_functions'][f]
        item = extract_keywords(item, use_cache = use_cache)
        item['id'] = id
        id = id + 1
        doc.metadata['job_functions'][f] = item
        print(item)

    for f in range(0,len(doc.metadata['job_requirements'])):
        item = doc.metadata['job_requirements'][f]
        item = extract_keywords(item, use_cache = use_cache)
        item['id'] = id
        id = id + 1
        doc.metadata['job_requirements'][f] = item
        print(item)

    with open(wpd_filepath(document.metadata['source']), "wb") as f:
        pickle.dump(doc, f)

    return doc

document = extract_document_keywords(document, use_cache = use_cache)
# Out:
# {'title': 'Análisis de requisitos y diseño de soluciones informáticas. Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos.', 'keywords': ['requisitos', 'diseño', 'soluciones informáticas', 'incompatibilidades', 'ambigüedades', 'inconsistencias'], 'id': 0}
# {'title': 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos.', 'keywords': ['equipos multidisciplinarios', 'propuestas técnicas', 'propuestas comerciales', 'licitaciones', 'proyectos informáticos', 'requisitos'], 'id': 1}
# {'title': 'Desarrollar y mantener plantillas y documentación estandarizada para agilizar el proceso de redacción.', 'keywords': ['Desarrollar', 'mantener', 'plantillas', 'documentación', 'estandarizada', 'agilizar', 'proceso'], 'id': 2}
# {'title': 'Participar en la definición de estrategias y enfoques para licitaciones, considerando las necesidades del cliente y los objetivos comerciales.', 'keywords': ['estrategias', 'licitaciones', 'cliente', 'objetivos'], 'id': 3}
# {'title': 'Recopilar y analizar información relativa a licitaciones previas al objeto de mejorar las futuras propuestas a realizar.', 'keywords': ['licitaciones', 'propuestas', 'análisis', 'información'], 'id': 4}
# {'title': 'Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI).', 'keywords': ['propuestas técnicas', 'propuestas comerciales', 'licitaciones', 'desarrollo de proyectos informáticos', 'CTTI'], 'id': 5}
# {'title': 'Experiencia en la realización de análisis funcionales y captura de requerimientos.', 'keywords': ['análisis funcionales', 'captura de requerimientos'], 'id': 6}
# {'title': 'Conocimientos técnicos sobre los principales componentes de administración electrónica del ámbito regional de Catalunya (CTTI, IMI, ACA, etc.).', 'keywords': ['administración electrónica', 'CTTI', 'IMI', 'ACA', 'Catalunya'], 'id': 7}
# {'title': 'Deseable disponer de conocimientos técnicos sobre arquitecturas Low Code (Outsystems, Appian, PowerPlatform).', 'keywords': ['Low Code', 'Outsystems', 'Appian', 'PowerPlatform', 'arquitecturas'], 'id': 8}
# {'title': 'Familiarizado con el uso de herramientas gráficas de modelaje de Arquitectura Empresarial (Archi, Visio, Draw.io o similares) y de modelaje de dominios funcionales (UML, Diagramas Entidad-Relación, Workflows, BPM, etc.).', 'keywords': ['Archi', 'Visio', 'Draw.io', 'UML', 'Diagramas Entidad-Relación', 'Workflows', 'BPM', 'Arquitectura Empresarial', 'modelaje'], 'id': 9}
# {'title': 'Conocimientos en metodologías Gestión de Proyectos Lean/Agile (Scrum, Kanban, Dual Track, etc).', 'keywords': ['Gestión de Proyectos', 'Lean', 'Agile', 'Scrum', 'Kanban', 'Dual Track'], 'id': 10}
# {'title': 'Conocimiento en metodologías de Gestión de Servicios TIC (ITIL, IT4IT, SecDevOps, etc.).', 'keywords': ['ITIL', 'IT4IT', 'SecDevOps', 'Gestión de Servicios TIC'], 'id': 11}
# {'title': 'Experiencia utilizando herramientas de productividad de Microsoft (Word, Excel, PowerPoint, SharePoint, Planner, etc.) e Inteligencia Artificial (ChatGPT, Copilot 360, Gemini o similares) para automatizar y mejorar ciertos procesos de redacción de las ofertas.', 'keywords': ['Microsoft', 'Word', 'Excel', 'PowerPoint', 'SharePoint', 'Planner', 'Inteligencia Artificial', 'ChatGPT', 'Copilot 360', 'Gemini', 'Automatizar', 'Procesos', 'Redacción', 'Ofertas'], 'id': 12}
# {'title': 'Excelentes habilidades de comunicación (especialmente escrita) en castellano y catalán.', 'keywords': ['comunicación', 'castellano', 'catalán'], 'id': 13}
# {'title': 'Habituado a trabajar en grupo de forma colaborativa.', 'keywords': ['trabajo en grupo', 'colaborativo'], 'id': 14}
# {'title': 'Capacidad resolutiva, proactividad, iniciativa y autonomía.', 'keywords': ['Capacidad resolutiva', 'proactividad', 'iniciativa', 'autonomía'], 'id': 15}

# %%
def adapt_task(task:str, task_list, language):

    if len(task_list) < 1: return (-1, task)
    
    class TaskId(TypedDict):
        taskid: Annotated[int, 'Id of the matched task_list or -1 if there is no match']

    task_selector_prompt = """1. Compare the description given by the user with each description in task_list,
- Use semantic similarity analysis to match both context and specific details.
2. Use the tool to return the taskid, or -1 if there is no match
task_list:

    {task_list}

/no_think"""

#   task_selector_prompt = """Find in the task_list the most compatible task.
# if there is no match, call the tool with the taskid=-1 and you are done.
# task_list:

#     {task_list}

# /no_think"""

    task_adapter_prompt = """You are a Job Task Adapter.
The user will provide a description of a task in their job.
1. Correct the task description given by using the **keywords**.
2. You can replace original words in the description with keywords as long as the original meaning remains and all together make sense.
3. Check the new description is different to the original description, if not, try again once.
Always use {language} language for the output.
If no keywords provided just translate and return the original.
Syntetize and summarize the in {max_words} words.
high light the **keywords** in **bold**.
keywords: 

    {keywords}

/no_think"""

    task_adapter_prompt_no_kw = """Use tool to Return a new_task with the text in {language} language.
/no_think"""

    try:
        response = summarize_text_llm(text = task, llm_model = llm_strong, name='task_selector',
            llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 6, "callbacks": [CallbackHandler()]},
            system_prompt = task_selector_prompt.format(task_list=[{'id':t['id'], 'title':t['title'] } for t in task_list]), response_format=ToolStrategy(TaskId))
       
        taskid = response['structured_response']['taskid']

    except Exception as e:
        print(e)
        taskid = -1

    keywords = [t['keywords'] for t in task_list if t['id'] == taskid]
    system_prompt = task_adapter_prompt_no_kw.format( language=language)
    if len(keywords) > 0: 
        system_prompt = task_adapter_prompt.format( language=language, max_words=len(task.split())*2, keywords=keywords )


    class TaskResponse(TypedDict):
        new_task: str

    response = summarize_text_llm(text = task, llm_model = llm_strong, name='task_adapter',
        llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 6, "callbacks": [CallbackHandler()]},
        system_prompt = system_prompt, 
        response_format=ToolStrategy(TaskResponse))

    return (taskid, response['structured_response']['new_task'])


# adapt_task(task = 'Elaboración de documentación para licitaciones e identificación de requisitos técnicos y funcionales.', 
#     task_list = document.metadata['job_functions']+document.metadata['job_requirements'],
#     language=document.metadata['language'])

# %%
import json

def adapt_cv(cv_data, url, use_cache=True):

    cv_adapted = None
    cv_adapted_file_path = cva_filepath(url)
    if os.path.exists(cv_adapted_file_path) and use_cache:
        with open(cv_adapted_file_path, "rb") as f:
            cv_adapted = json.load(f)
            print("loaded from cache file", cv_adapted_file_path)
    else:
        cv_adapted = dict(cv_data)
        task_list = (document.metadata['job_functions'] + document.metadata['job_requirements'])
        cv_adapted['title'] = document.metadata['job_position_title']

        for e in range(0, len(cv_adapted['experiences'])):
            for t in range(0, len(cv_adapted['experiences'][e]['description'])):
                orig_task = cv_adapted['experiences'][e]['description'][t]
                try:
                    (taskid, new_task) = adapt_task(task = orig_task, task_list = task_list, language=document.metadata['language'])
                except Exception as ex:
                    print(ex)
                    (taskid, new_task) = (-1, orig_task)    
                base_task = next(iter([t for t in task_list if t['id'] == taskid]), None)
                display({'orig_task':orig_task,
                        'new_task':new_task,
                        'base_task':base_task })
                cv_adapted['experiences'][e]['description'][t] = new_task
                task_list = [t for t in task_list if t['id'] != taskid]
        
        with open(cv_adapted_file_path, "w") as f:
            json.dump(cv_adapted, f, indent=4)

        display(task_list)
        
    display(cv_adapted['experiences'])


    return cv_adapted

cv_adapted = adapt_cv(cv_data, job_offer_url, use_cache=use_cache)
# Out:
# {'orig_task': 'Elaboración de documentación para licitaciones e **identificación de requisitos** técnicos y funcionales, con enfoque en **diseño**, **soluciones informáticas** y resolución de **incompatibilidades**, **ambigüedades** y **inconsistencias**.',
#  'new_task': 'Elaboración de documentación para licitaciones e **identificación de requisitos** técnicos y funcionales, con enfoque en **diseño**, **soluciones informáticas** y resolución de **incompatibilidades**, **ambigüedades** y **inconsistencias**.',
#  'base_task': {'title': 'Análisis de requisitos y diseño de soluciones informáticas. Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos.',
#   'keywords': ['requisitos',
#    'diseño',
#    'soluciones informáticas',
#    'incompatibilidades',
#    'ambigüedades',
#    'inconsistencias'],
#   'id': 0}}
# {'orig_task': 'Coordinación de **equipos multidisciplinarios** y seguimiento de **proyectos informáticos** y servicios.',
#  'new_task': '**Coordinación de equipos multidisciplinarios** y seguimiento de **proyectos informáticos** y servicios.',
#  'base_task': {'title': 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos.',
#   'keywords': ['equipos multidisciplinarios',
#    'propuestas técnicas',
#    'propuestas comerciales',
#    'licitaciones',
#    'proyectos informáticos',
#    'requisitos'],
#   'id': 1}}
# Recursion limit of 6 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT
# {'orig_task': 'Facilitar la comunicación con proveedores externos para garantizar la calidad y cumplimiento de acuerdos.',
#  'new_task': 'Facilitar la comunicación con proveedores externos para garantizar la calidad y cumplimiento de acuerdos',
#  'base_task': None}
# {'orig_task': "Promoting digital transformation and facilitating users' transition to new technologies.",
#  'new_task': 'Promover la transformación digital y facilitar a los usuarios la transición a nuevas tecnologías.',
#  'base_task': None}
# {'orig_task': '**Gestión de Proyectos** de presupuestos y ejecución bajo enfoques **Agile** y **Lean** alineados con el Plan estratégico.',
#  'new_task': '**Gestión de Proyectos** de presupuestos y ejecución bajo enfoques **Agile** y **Lean**, alineados con el Plan estratégico.',
#  'base_task': {'title': 'Conocimientos en metodologías Gestión de Proyectos Lean/Agile (Scrum, Kanban, Dual Track, etc).',
#   'keywords': ['Gestión de Proyectos',
#    'Lean',
#    'Agile',
#    'Scrum',
#    'Kanban',
#    'Dual Track'],
#   'id': 10}}
# {'orig_task': 'Evaluación y mitigación de riesgos en servicios y proyectos de tecnología de la información y las comunicaciones.',
#  'new_task': 'Evaluación y mitigación de riesgos en servicios y proyectos de tecnología de la información y las comunicaciones',
#  'base_task': None}
# {'orig_task': 'Propuesta y desarrollo de **iniciativa** con **autonomía** y **proactividad** para lograr mejora continua.',
#  'new_task': 'Propuesta y desarrollo de **iniciativa** con **autonomía** y **proactividad** para lograr mejora continua.',
#  'base_task': {'title': 'Capacidad resolutiva, proactividad, iniciativa y autonomía.',
#   'keywords': ['Capacidad resolutiva',
#    'proactividad',
#    'iniciativa',
#    'autonomía'],
#   'id': 15}}
# Recursion limit of 6 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT
# {'orig_task': 'Gobernanza operativa para la gestión de recursos y despliegue de servicios.',
#  'new_task': 'Gobernanza operativa para la gestión de recursos y despliegue de servicios',
#  'base_task': None}
# Recursion limit of 6 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT
# {'orig_task': 'Operational tracking, incident resolution, and prevention of technological obsolescence.',
#  'new_task': 'Seguimiento operacional, resolución de incidentes y prevención de la obsolescencia tecnológica.',
#  'base_task': None}

# %%
def extract_skills(content, base_skills_list, language):

    skill_extractor_prompt = """Find the soft skills listed in the soft_skills_list in the text and return the finded in a list.
Use the name of the text in the returned list, use {language} language.

soft_skills_list: {soft_skills}

/no_think"""
    skill_extractor_prompt = """extract the soft skills mentioned the text as they are. do not invent. use tool call to return a skillsResponse"""

# base_skills_list: {base_skills_list}

    class skillsResponse(TypedDict):
        soft_skills: list[str]

    try:
        response = summarize_text_llm(text = content, llm_model = llm_strong, name='skill_extractor',
            # llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 6, "callbacks": [CallbackHandler()]},
            system_prompt = skill_extractor_prompt.format(base_skills_list=base_skills_list, language=language), response_format=ToolStrategy(skillsResponse))

        return response['structured_response']['soft_skills']

    except Exception as e:
        print(e)
        return []


# base_skills_list = [item for value_list in soft_skill.values() for item in value_list]

# extracted_skills = extract_skills(content = document.page_content, base_skills_list=base_skills_list, language=document.metadata['language'])

# extracted_skills

# %%
import base64

def encode_base64(data):
    if isinstance(data, str):
        data = data.encode('utf-8')
    
    encoded = base64.b64encode(data)
    return encoded.decode('utf-8')

def decode_base64(encoded_data):
    decoded = base64.b64decode(encoded_data.encode('utf-8'))
    return decoded.decode('utf-8')

# Test encoding
original_text = """secret"""
encoded = encode_base64(original_text)
print(f"Original: {original_text}")
print(f"Encoded:  {encoded}")

# Test decoding
decoded = decode_base64(encoded)
print(f"Decoded:  {decoded}")

# %%
from jinja2 import Environment, FileSystemLoader
import re

def render_cv(cv_data):

    # Create environment and load template
    env = Environment(loader=FileSystemLoader('./data/'))
    template = env.get_template('cv_template_es.html')

    cv_data['contact_info'] = decode_base64(cv_data['contact_info'])
    cv_data['name'] = decode_base64(cv_data['name'])

    for e in range(0, len(cv_data['experiences'])):
        for t in range(0, len(cv_data['experiences'][e]['description'])):
            cv_data['experiences'][e]['description'][t] = re.sub(r'\*\*(.*?)\*\*', r'<strong>\1</strong>', cv_data['experiences'][e]['description'][t])

    # Render template with model
    output = template.render(cv_data)

    # Print or save output
    with open(cv_filepath(job_offer_url), "w") as f:
        f.write(output)

render_cv(dict(cv_adapted))

# %%
# Save html file to pdf
import pdfkit

def convert_html_to_pdf(html_path, pdf_path):
    html_content = open(html_path).read()
    pdfkit.from_string(html_content, pdf_path)
    print(f"PDF saved at {pdf_path}")


convert_html_to_pdf(cv_filepath(job_offer_url), pdf_filepath(job_offer_url))
