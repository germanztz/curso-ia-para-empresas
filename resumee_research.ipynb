# %%
import json
import re

# TODO
# --OK Usar idioma de la oferta 
# Afinar y aprobar en una segunda pasada la job description para evitar repeticiones, concatenaciones de keywords sin sentido
# traducir titulos de curriculum
# --OK Extraer soft skills generales (evitar usarlas en las job description?)
# --OK usar modelo qwen3:32b 
# optimizar tags html en template
# leer curriculum original para escrapear los datos
# --OK generar pdf
# generar documento editable word? odf? para corregir

wpd_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.document.wpd"
cva_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv_adapted.json"
cv_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.html"
pdf_filepath = lambda x: f"workspace/{re.sub(r'[^\w]+', '_', x)}.cv.pdf"

cv_file_path = 'data/cv_data_es.json'
soft_skill_file_path = 'data/soft_skill_es.json'
cv_data = {}
soft_skill = {}
# Load JSON file into a dictionary
with open(cv_file_path, 'r') as f:
    cv_data = json.load(f)
with open(soft_skill_file_path, 'r') as f:
    soft_skill = json.load(f)

use_cache=True

job_offer_url = 'https://www.linkedin.com/jobs/view/4362181901'
# job_offer_url = 'https://www.linkedin.com/jobs/view/4317166787'
# job_offer_url = 'https://selection.uoc.edu/web/offersjob/offerdetails.aspx?offerID=5464EA521BB0E0207C9DA853CA6F8505F72B82E3D56D2CAD90882623EBEE1FA7'

# %%
from tools import web_operations
import pickle
from langchain_core.documents import Document
import re
import os

def load_document(url, use_cache=True):

    document = None
    job_offer_file_path = wpd_filepath(url)
    if os.path.exists(job_offer_file_path) and use_cache:
        with open(job_offer_file_path, "rb") as f:
            document = pickle.load(f)
            print("loaded from cache file", job_offer_file_path)
    else:
        document = web_operations.scrape_webpages.invoke(input={'url':url, 'include_links':False })[0]
        with open(job_offer_file_path, "wb") as f:
            pickle.dump(document, f)
        print("loaded from url")
        
    return document

document = load_document(job_offer_url, use_cache=use_cache)
print(document.metadata['title'])
# Out:
# loaded from cache file workspace/https_www_linkedin_com_jobs_view_4362181901.document.wpd
# DXC Technology hiring Analista técnico/funcional informático/a in Sant Cugat del Vallès, Catalonia, Spain | LinkedIn

# %%
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langchain_ollama import ChatOllama
from langfuse.langchain import CallbackHandler

llm_strong = ChatOllama(model='qwen3', reasoning=False)
llm_ligth = ChatOllama(model='qwen3', reasoning=False)
llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

def summarize_text_llm(text: str, 
    system_prompt = "",
    llm_model = llm_ligth,
    llm_config = llm_config,
    response_format=None,
    name="summarization_agent",
    ) :

    agent = create_agent(name=name, model=llm_model, system_prompt=system_prompt, response_format=response_format )
    return agent.invoke({"messages": [("user", text)]}, config=llm_config)

# %%
from typing import Annotated, List, Dict, Any, Optional
from langchain_core.documents import Document
from typing import TypedDict, Literal
from pathlib import Path
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langfuse.langchain import CallbackHandler

# Prompt para el analizador de ofertas
job_analyzer_prompt = """You are a precise job offer analyzer. Your task is to extract and structure information from job offers according to the provided schema.

Key instructions:
1. **Job Title Extraction**: Extract the exact job position title from the document
2. **Company Description**: Extract a Concise, clear, human-friendly and jargon-free company summary, focus on the company goals and values
3. **Job Functions**: Extract all job responsibilities exactly as written in the document
4. **Job Requirements**: Extract all formal requirements exactly as written in the document
5. **Language Detection**: Finally, detect the language of the text. It can be Spanish or Catalan or English

Important: 
- Never translate, Preserve all original wording and language
- Extract verbatim content from the document
- Return only the structured data matching the schema
- Do not add any explanations or additional text

Output Format:

1. **job_position_title**:
2. **company_description**:
3. **job_functions**:
    - ''
4. **job_requirements**:
    - ''
5. **language**: Spanish or Catalan or English

/no_think
"""

llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

class JobOffer(BaseModel):
    language: Literal['Spanish', 'Catalan', 'English'] = Field(description="The detected language")
    job_position_title: str = Field(description="Job title")
    company_description: str = Field(description="Concise, clear, human-friendly and jargon-free company summary")
    job_functions: list[str] = Field(description="Verbatim job responsibilities")
    job_requirements: list[str] = Field(description="Verbatim formal requirements")

job_analyzer_agt = create_agent(name='job_analyzer', 
    model=ChatOllama(
        model='qwen3', 
        reasoning=False,
        temperature=0.0,
        top_p=0.1,
        top_k=20,
        repeat_penalty=1.1,
        seed=42),
    system_prompt=job_analyzer_prompt , 
    response_format=ToolStrategy(JobOffer)
)

def extract_job_parts(content) -> JobOffer:
    """Agente que analiza la oferta laboral y extrae información"""
    
    try:
        response = job_analyzer_agt.invoke(input = {"messages": [HumanMessage(content=content)]})
        return response['structured_response']

    except Exception as e:
        print(f"Error: {e}")
        raise


# if use_cache and all(key in document.metadata for key in ['job_position_title']):
#     return document.metadata

content = f"# {document.metadata['title']}\n{document.page_content}"

job_offer = extract_job_parts(content = content)
display(job_offer.model_dump())

document.metadata.update(job_offer.model_dump())
with open(wpd_filepath(document.metadata['source']), 'wb') as f:
    pickle.dump(document, f)
# Out:
# {'language': 'Spanish',
#  'job_position_title': 'Analista técnico/funcional informático/a',
# ...

# %%
from typing import Annotated, List, Dict, Any, Optional
from langchain_core.documents import Document
from typing import TypedDict, Literal
from pathlib import Path
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langfuse.langchain import CallbackHandler
from IPython.display import Image
import pickle

class JobOffer(BaseModel):
    language: Literal['Spanish', 'Catalan', 'English'] = Field(description="The detected language")
    job_position_title: str = Field(description="Job title")
    company_description: str = Field(description="Concise, clear, human-friendly and jargon-free company summary")
    job_functions: list[str] = Field(description="Verbatim job responsibilities")
    job_requirements: list[str] = Field(description="Verbatim formal requirements")

class AgentState(TypedDict):
    content: str
    job_analyzer_response: Optional[str]
    tool_agent_response: Optional[Dict[str, Any]]

# Prompt para el analizador de ofertas
job_analyzer_prompt = """You are a precise job offer analyzer. Your task is to extract and structure information from job offers according to the provided schema.

Key instructions:
1. **Job Title Extraction**: Extract the exact job position title from the document
2. **Company Description**: Extract a Concise, clear, human-friendly and jargon-free company summary, focus on the company goals and values
3. **Job Functions**: Extract all job responsibilities exactly as written in the document
4. **Job Requirements**: Extract all formal requirements exactly as written in the document
5. **Language Detection**: Finally, detect the language of the text. It can be Spanish or Catalan or English

Important: 
- Never translate, Preserve all original wording and language
- Extract verbatim content from the document
- Return only the structured data matching the schema
- Do not add any explanations or additional text

Output Format:

1. **job_position_title**:
2. **company_description**:
3. **job_functions**:
    - ''
4. **job_requirements**:
    - ''
5. **language**: Spanish or Catalan or English
"""

# Prompt para el agente de herramientas
tool_agent_prompt = """Use tool to generate an structured response based on the user input, discard the information not specified in the structured response object /no_think"""

llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

def job_analyzer_node(state: AgentState):
    """Agente que analiza la oferta laboral y extrae información"""
    
    # Crear el agente de análisis
    job_analyzer_agent = create_agent(name='job_analyzer', 
        model=ChatOllama(
            model='llama3.2', 
            reasoning=False,
            temperature=0.0,
            top_p=0.1,
            top_k=20,
            repeat_penalty=1.1,
            seed=42),
        system_prompt=job_analyzer_prompt )
    
    response = job_analyzer_agent.invoke(input = {"messages": [HumanMessage(content=state["content"])]})
    return {'job_analyzer_response': response['messages'][-1].content}

def tool_node(state: AgentState):
    """Agente que estructura la respuesta usando el formato esperado"""
    # Crear el agente de herramientas
    tool_agent = create_agent(name='tool_agent', 
        model=ChatOllama(model='qwen3', reasoning=False), 
        system_prompt=tool_agent_prompt, 
        response_format=ToolStrategy(JobOffer) )

    response = tool_agent.invoke(input = {"messages": [HumanMessage(content=state["job_analyzer_response"])]})
    
    # Aquí deberíamos parsear la respuesta y convertirla en el formato JobOffer
    # Para este ejemplo, simplemente devolvemos la respuesta como está
    return {"tool_agent_response": response['structured_response']}

def create_job_analysis_graph():
    """Crea el grafo con dos agentes"""
    workflow = StateGraph(AgentState)
    
    # Agregar nodos
    workflow.add_node("job_analyzer", job_analyzer_node)
    workflow.add_node("tool_agent", tool_node)
    
    # Definir las conexiones
    workflow.add_edge(START, "job_analyzer")
    workflow.add_edge("job_analyzer", "tool_agent")
    workflow.add_edge("tool_agent", END)
    
    # Crear el grafo completo
    app = workflow.compile()

    display(Image(app.get_graph().draw_mermaid_png()))

    return app

# Ejemplo de uso del grafo
def extract_job_parts_graph(content: str):
    """Función para ejecutar el análisis usando el grafo"""
    try:
        # Crear el grafo
        graph = create_job_analysis_graph()
        
        # Ejecutar el grafo
        initial_state = {"content": content}
        result = graph.invoke(initial_state, config=llm_config)

        return result["tool_agent_response"]
        
    except Exception as e:
        print(f"Error: {e}")
        raise

# Ejemplo de cómo usarlo con un documento
def process_document(document: Document):
    """Procesa un documento usando el grafo de agentes"""
    # Crear el contenido del documento
    content = f"# {document.metadata['title']}\n{document.page_content}"
    
    # Ejecutar el análisis con el grafo
    job_offer = extract_job_parts_graph(content)
    
    display(job_offer)
    # Actualizar los metadatos del documento
    document.metadata.update(job_offer)
    
    # Guardar el documento
    with open(wpd_filepath(document.metadata['source']), 'wb') as f:
        pickle.dump(document, f)

process_document(document)
# Out:
# JobOffer(language='Spanish', job_position_title='Analista técnico/funcional informático/a', company_description='DXC Technology es una compañía global de servicios profesionales cuya misión es liderar la transformación digital de nuestros clientes asesorándoles y guiándoles en la aplicación de la tecnología para obtener los mejores resultados que permitan incrementar la competitividad de sus empresas.', job_functions=['Análisis de requisitos y diseño de soluciones informáticas.', 'Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos.', 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos.', 'Desarrollar y mantener plantillas y documentación estandarizada para agilizar el proceso de redacción.', 'Participar en la definición de estrategias y enfoques para licitaciones, considerando las necesi
# ...

# %%
keyword_extractor_prompt = """Extract the keywords in the field of computer science and project management.
Keep the keywords short and simple.
Stick to the text, Do not invent new words.
/no_think"""

class Keywords(TypedDict):
    keywords: list[str]

def extract_keywords(item, use_cache = True):
    keywords = item['keywords'] if type(item) is dict else []
    item = item['title'] if type(item) is dict else item

    if len(keywords) > 0 and use_cache:
        return {'title':item, 'keywords': keywords}
    try:
        response = summarize_text_llm(text=item, name='keyword_extractor', llm_model = llm_ligth,
        llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]},
        response_format=ToolStrategy(Keywords),  system_prompt = keyword_extractor_prompt, )

        keywords = response['structured_response']['keywords']
    except Exception as e:
        print(e)
    return {'title':item, 'keywords': keywords}
  
# extract_keywords(document.metadata['job_requirements'][0])

# %%
def extract_document_keywords(doc: Document, use_cache = True):

    id = 0

    for f in range(0,len(doc.metadata['job_functions'])):
        item = doc.metadata['job_functions'][f]
        item = extract_keywords(item, use_cache = use_cache)
        item['id'] = id
        id = id + 1
        doc.metadata['job_functions'][f] = item
        print(item)

    for f in range(0,len(doc.metadata['job_requirements'])):
        item = doc.metadata['job_requirements'][f]
        item = extract_keywords(item, use_cache = use_cache)
        item['id'] = id
        id = id + 1
        doc.metadata['job_requirements'][f] = item
        print(item)

    with open(wpd_filepath(document.metadata['source']), "wb") as f:
        pickle.dump(doc, f)

    return doc

document = extract_document_keywords(document, use_cache = use_cache)
# Out:
# {'title': 'Análisis de requisitos y diseño de soluciones informáticas.', 'keywords': ['requisitos', 'diseño', 'soluciones informáticas'], 'id': 0}
# {'title': 'Identificación de posibles incompatibilidades entre requisitos planteados, ambigüedades e inconsistencias en requisitos.', 'keywords': ['requisitos', 'incompatibilidades', 'ambigüedades', 'inconsistencias'], 'id': 1}
# {'title': 'Colaborar estrechamente con equipos multidisciplinarios para redactar y revisar propuestas técnicas y comerciales para licitaciones relativas al desarrollo de proyectos informáticos. Asegurando su precisión, claridad y cumplimiento de requisitos.', 'keywords': ['colaboración', 'equipo multidisciplinario', 'propuestas técnicas', 'licitaciones', 'proyectos informáticos', 'precisión', 'claridad', 'requisitos'], 'id': 2}
# ...

# %%
class TaskId(TypedDict):
    taskid: Annotated[int, 'Id of the matched task_list or -1 if there is no match']

class TaskResponse(TypedDict):
    new_task: str


task_selector_prompt = """1. Compare the description given by the user with each description in task_list,
- Use semantic similarity analysis to match both context and specific details.
2. Use the tool to return the taskid, or -1 if there is no match
task_list:

    {task_list}

/no_think"""

task_adapter_prompt = """You are a Job Task Adapter.
The user will provide a description of a task in their job.
1. Correct the task description given by using the **keywords**.
2. You can replace original words in the description with keywords as long as the original meaning remains and all together make sense.
3. Check the new description is different to the original description, if not, try again once.
Always use {language} language for the output.
If no keywords provided just translate and return the original.
Syntetize and summarize the in {max_words} words.
high light the **keywords** in **bold**.
keywords: 

    {keywords}

/no_think"""

task_adapter_prompt_no_kw = """Use tool to Return a new_task with the text in {language} language.
/no_think"""

def adapt_task(task:str, task_list, language):

    if len(task_list) < 1: return (-1, task)

    try:
        response = summarize_text_llm(text = task, llm_model = llm_strong, name='task_selector',
            llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 6, "callbacks": [CallbackHandler()]},
            system_prompt = task_selector_prompt.format(task_list=[{'id':t['id'], 'title':t['title'] } for t in task_list]), response_format=ToolStrategy(TaskId))
       
        taskid = response['structured_response']['taskid']

    except Exception as ex:
        print(ex)
        taskid = -1

    keywords = [t['keywords'] for t in task_list if t['id'] == taskid]
    system_prompt = task_adapter_prompt_no_kw.format( language=language)
    if len(keywords) > 0: 
        system_prompt = task_adapter_prompt.format( language=language, max_words=len(task.split())*2, keywords=keywords )


    response = summarize_text_llm(text = task, llm_model = llm_strong, name='task_adapter',
        llm_config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 6, "callbacks": [CallbackHandler()]},
        system_prompt = system_prompt, 
        response_format=ToolStrategy(TaskResponse))

    return (taskid, response['structured_response']['new_task'])


# adapt_task(task = cv_data['experiences'][0]['description'][2], 
#     task_list = document.metadata['job_functions']+document.metadata['job_requirements'],
#     language=document.metadata['language'])

# %%
import json

def adapt_cv(cv_data, url, use_cache=True):

    cv_adapted = None
    cv_adapted_file_path = cva_filepath(url)
    if os.path.exists(cv_adapted_file_path) and use_cache:
        with open(cv_adapted_file_path, "rb") as f:
            cv_adapted = json.load(f)
            print("loaded from cache file", cv_adapted_file_path)
    else:
        cv_adapted = dict(cv_data)
        task_list = (document.metadata['job_functions'] + document.metadata['job_requirements'])
        cv_adapted['title'] = document.metadata['job_position_title']

        for e in range(0, len(cv_adapted['experiences'])):
            for t in range(0, len(cv_adapted['experiences'][e]['description'])):
                orig_task = cv_adapted['experiences'][e]['description'][t]
                try:
                    (taskid, new_task) = adapt_task(task = orig_task, task_list = task_list, language=document.metadata['language'])
                except Exception as ex:
                    print(ex)
                    (taskid, new_task) = (-1, orig_task)    
                base_task = next(iter([t for t in task_list if t['id'] == taskid]), None)
                display({'orig_task':orig_task,
                        'new_task':new_task,
                        'base_task':base_task })
                cv_adapted['experiences'][e]['description'][t] = new_task
                task_list = [t for t in task_list if t['id'] != taskid]
        
        with open(cv_adapted_file_path, "w") as f:
            json.dump(cv_adapted, f, indent=4)

        display(task_list)
        
    display(cv_adapted['experiences'])


    return cv_adapted

cv_adapted = adapt_cv(cv_data, job_offer_url, use_cache=use_cache)
# Out:
# loaded from cache file workspace/https_www_linkedin_com_jobs_view_4362181901.cv_adapted.json
# [{'title': 'Gerente de operaciones TIC',
#   'location': 'en CTTI (2025)',
#   'description': ['Elaboración de documentación para licitaciones e identificación de requisitos técnicos y funcionales relacionados con el diseño de soluciones informáticas.',
#    'Coordinación de equipos técnicos corporativos y seguimiento de proyectos y servicios',
#    'Facilitar la comunicación con proveedores externos para garantizar la calidad y cumplimiento de acuerdos.',
#    'Promover la transformación digital y facilitar la transición de los usuarios hacia nuevas tecnologías.',
#    'Gestión de presupuestos y ejecución de proyectos según el Plan estratégico',
#    'Evaluación y mitigación de riesgos en servicios y proyectos de tecnología de la información y las comunicaciones.',
#    'Propuesta y desarrollo de iniciativas de mejora continua.',
# ...

# %%
skill_extractor_prompt = """
You are a semantic matcher specialized in computer science and project management terminology.

Given a list of technical terms (keywords_list) and ONE target_term, your task is to select the one and most semantically equivalent or closely related term from the list.

IMPORTANT: You MUST ONLY respond with a term that BEST matches one of the keywords in the keywords_list. Do not invent new terms, do not modify existing terms, and do not return the target_term itself if it's not in the keywords_list.

If none of the provided keywords accurately match the meaning of the input term within this domain, respond 'None'.

Context:
- Domain: Computer Science & Project Management
- keywords_list: {keywords}

Respond ONLY with the best matching keyword from the list, or 'None' if no match is found.
/no_think"""

def find_skill_match(skill, keywords):

    match = None
    try:
        agent = create_agent(name='skill_extractor', 
            model=ChatOllama(
                model='phi4-mini', 
                reasoning=False, 
                temperature=0.1, 
                num_ctx=4096, 
                num_predict=100,  
                repeat_penalty=1.1  
            ), 
            system_prompt=skill_extractor_prompt.format(keywords=keywords), 
        )
        match = agent.invoke(
            input={"messages": [("user", 'target_term: '+skill)]}, 
            config=llm_config,
            # debug=True
        )['messages'][1].content

        if (match in ['None']+list(keywords)):
            print(skill,'-->',match)
        else:
            print(skill,'???',match)

    except Exception as e:
        print(e)

    return match

def extract_skills_from_task_keywords(skills: list, tasks: list):
    
    keywords = set([keyword for task in tasks for keyword in task['keywords']])

    print(skills)
    print('-'*100)
    print(keywords)
    print('-'*100)
    matches = dict()

    for skill in skills:
        match =  find_skill_match(skill, keywords)

        if (match in keywords):
            matches[skill] = match

    return matches

base_skills_list = [item for value_list in soft_skill.values() for item in value_list]
job_offer_tasks = (document.metadata['job_functions'] + document.metadata['job_requirements'])

extracted_skills = extract_skills_from_task_keywords(base_skills_list, job_offer_tasks)
display('Matches: '+str(len(extracted_skills)), extracted_skills)

cv_adapted['extracted_skills'] = set(extracted_skills.values())
# Out:
# ['Iniciativa', 'Orientación al logro', 'Planificación y organización', 'Preocupación por el orden y la calidad', 'Dirección de personas', 'Liderazgo', 'Trabajo en equipo y cooperación', 'Autoconfianza', 'Autocontrol', 'Compromiso con la organización', 'Flexibilidad y gestión del cambio', 'Comunicación', 'Empatía', 'Negociación', 'Networking', 'Orientación al cliente', 'Aprendizaje y utilización de conocimientos', 'Creatividad', 'Orientación estratégica', 'Pensamiento analítico', 'Pensamiento conceptual']
# ----------------------------------------------------------------------------------------------------
# ...

# %%
import base64

def encode_base64(data):
    if isinstance(data, str):
        data = data.encode('utf-8')
    
    encoded = base64.b64encode(data)
    return encoded.decode('utf-8')

def decode_base64(encoded_data):
    decoded = base64.b64decode(encoded_data.encode('utf-8'))
    return decoded.decode('utf-8')

# Test encoding
original_text = """secret"""
encoded = encode_base64(original_text)
print(f"Original: {original_text}")
print(f"Encoded:  {encoded}")

# Test decoding
decoded = decode_base64(encoded)
print(f"Decoded:  {decoded}")
# Out:
# Original: secret
# Encoded:  c2VjcmV0
# Decoded:  secret

# %%
from jinja2 import Environment, FileSystemLoader
import re

def render_cv(cv_data):

    # Create environment and load template
    env = Environment(loader=FileSystemLoader('./data/'))
    template = env.get_template('cv_template_es.html')

    cv_data['contact_info'] = decode_base64(cv_data['contact_info'])
    cv_data['name'] = decode_base64(cv_data['name'])

    for e in range(0, len(cv_data['experiences'])):
        for t in range(0, len(cv_data['experiences'][e]['description'])):
            cv_data['experiences'][e]['description'][t] = re.sub(r'\*\*(.*?)\*\*', r'<strong>\1</strong>', cv_data['experiences'][e]['description'][t])

    # Render template with model
    output = template.render(cv_data)

    # Print or save output
    with open(cv_filepath(job_offer_url), "w") as f:
        f.write(output)

render_cv(dict(cv_adapted))

# %%
# Save html file to pdf
import pdfkit

def convert_html_to_pdf(html_path, pdf_path):
    html_content = open(html_path).read()
    pdfkit.from_string(html_content, pdf_path)
    print(f"PDF saved at {pdf_path}")


convert_html_to_pdf(cv_filepath(job_offer_url), pdf_filepath(job_offer_url))
# Out:
# PDF saved at workspace/https_www_linkedin_com_jobs_view_4362181901.cv.pdf
