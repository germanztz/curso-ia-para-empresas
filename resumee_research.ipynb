# %%
# 1. Set environment variables

import json
import re
import os

# TODO traducir titulos de curriculum
# TODO adaptar summary
# --OK Usar idioma de la oferta 
# --OK Afinar y aprobar en una segunda pasada la job description para evitar repeticiones, concatenaciones de keywords sin sentido
# --OK Extraer soft skills generales (evitar usarlas en las job description?)
# --OK usar modelo qwen3:32b 
# --OK leer curriculum original para escrapear los datos
# --OK generar pdf
# --OK generar documento editable word? odf? para corregir
# --NO optimizar tags html en template

cv_original_file_path = 'workspace/cv_original.odt'
job_offer_url = 'https://www.linkedin.com/jobs/view/4362181901'
# job_offer_url = 'https://www.linkedin.com/jobs/view/4317166787'
# job_offer_url = 'https://selection.uoc.edu/web/offersjob/offerdetails.aspx?offerID=5464EA521BB0E0207C9DA853CA6F8505F72B82E3D56D2CAD90882623EBEE1FA7'

url_filepath = lambda x: re.sub(r'[^\w]+', '_', x)
cv_original_file_name = os.path.splitext(os.path.basename(cv_original_file_path))[0]
job_offer_json = f"workspace/job_offer.{url_filepath(job_offer_url)}.json"
cv_original_json = f"workspace/{cv_original_file_name}.json"
cv_adapted_json = f"workspace/{cv_original_file_name}_adapted_to_{url_filepath(job_offer_url)}.json"
cv_adapted_odt = f"workspace/{cv_original_file_name}_adapted_to_{url_filepath(job_offer_url)}.odt"
soft_skill_file_path = 'data/soft_skill_es.json'

soft_skill = {}
with open(soft_skill_file_path, 'r') as f:
    soft_skill = json.load(f)

base_skills_list = [item for value_list in soft_skill.values() for item in value_list]

use_cache=True

print('curriculum:',cv_original_file_path, 'job offer:',job_offer_url)

# %%
# 2. Extract strunctured JobOffer from URL using LLM

from tools import web_operations
from langchain_core.documents import Document
from typing import Annotated, List, Dict, Any, Optional
from langchain_core.documents import Document
from langchain_core.messages import SystemMessage, HumanMessage
from typing import TypedDict, Literal
from pathlib import Path
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langfuse.langchain import CallbackHandler
import pickle
import json
import os

# # Prompt para el analizador de ofertas
    # job_analyzer_prompt = """You are a precise job offer analyzer. Your task is to extract and structure information from job offers according to the provided schema.

    # Key instructions:
    # 1. **Job Title Extraction**: Extract the exact job position title from the document
    # 2. **Company Description**: Extract a Concise, clear, human-friendly and jargon-free company summary, focus on the company goals and values
    # 3. **Job Functions**: Extract all job responsibilities exactly as written in the document
    # 4. **Job Requirements**: Extract all formal requirements exactly as written in the document
    # 5. **Language Detection**: Finally, detect the language of the text. It can be Spanish or Catalan or English

    # Important: 
    # - Never translate, Preserve all original wording and language
    # - Extract verbatim content from the document
    # - Return only the structured data matching the schema
    # - Do not add any explanations or additional text

    # Output Format:

    # 1. **job_position_title**:
    # 2. **company_description**:
    # 3. **job_functions**:
    #     - ''
    # 4. **job_requirements**:
    #     - ''
    # 5. **language**: Spanish or Catalan or English

    # /no_think
    # """

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, temperature=0.0,  top_p=0.1, top_k=20, repeat_penalty=1.1, seed=42)

class JobOffer(BaseModel):
    language: Literal['Spanish', 'Catalan', 'English'] = Field(description="Primary language of the document. *Infer from lexical patterns and section headers.*")    
    job_position_title: str = Field(description="Job title")
    company_description: str = Field(description="Concise, clear, human-friendly and jargon-free company summary")
    job_functions: list[str] = Field(description="Verbatim job responsibilities")
    job_requirements: list[str] = Field(description="Verbatim formal requirements")

def extract_job_parts(content) -> JobOffer:
    """Agente que analiza la oferta laboral y extrae información"""
    
    try:
        return llm.with_structured_output(JobOffer).invoke(
            input = [
                # SystemMessage(content=job_analyzer_prompt),
                HumanMessage(content=content)
            ],
            config = config)    

    except Exception as e:
        print(f"Error: {e}")
        raise


# Check if the output JSON file exists
if os.path.exists(job_offer_json):
    print(f"Loading job offer data from {job_offer_json}...")
    with open(job_offer_json, "r", encoding="utf-8") as f:
        job_offer = json.load(f)
else:
    document = web_operations.scrape_webpages.invoke(input={'url':job_offer_url, 'include_links':False, 'cache_time':99999 })[0]
    print("Page title:", document.metadata['title'])

    print("Extracting job offer from scratch...")
    job_offer = extract_job_parts(content = document.page_content).model_dump()

    print(f"Saving job offer to {job_offer_json}...")
    with open(job_offer_json, "w", encoding="utf-8") as f:
        json.dump(job_offer, f, ensure_ascii=False, indent=2)

print("Position title:", job_offer['job_position_title'])

# %%
# 3. Extract resumee file text content indexed

from tools import odt_tools
from IPython.display import Markdown

cv_document = odt_tools.OdtDocument(cv_original_file_path)
cv_content_indexed = cv_document.get_indexed_text(markdown=True)
cv_content = '\n'.join(cv_content_indexed.values())
# display(Markdown(cv_content))
cv_content_indexed = [{'node_id':k, 'text':v} for k,v in cv_content_indexed.items() if v]
print(str(cv_content_indexed)[:100])

# %%
# 4. Extract structured CVData using LLM

from typing import List, Optional
from pydantic import BaseModel, Field
import json
import os

class DocLine(BaseModel):
    node_id: int = Field(description="Unique identifier; used for tracing source position in document")
    text: str = Field(description="Verbatim Raw plain-text content of the node")

class CVData(BaseModel):
    name: DocLine = Field(description="Candidate's full legal or professional name")
    professional_title: DocLine = Field(description="Verbatim Core job title or role identity (e.g., 'Data Scientist', 'DevOps Engineer')")
    professional_summary: List[DocLine] = Field(description="Verbatim Summary or objective statement highlighting experience, skills, and value proposition; often under headings like 'Professional Summary', 'Profile', or 'About Me'")
    contact_info: List[DocLine] = Field(description="Verbatim Structured contact lines including email, phone, website, LinkedIn, or address - may appear as icons or plaintext in header")
    education: List[DocLine] = Field(description="Verbatim Academic entries including institution name, degree, dates; may include GPA or honors - under section 'Education', 'Academic Background', etc.")
    languages: List[DocLine] = Field(description="List of spoken/written languages with proficiency (e.g., 'English (Native)', 'Spanish (Fluent)') - section labeled 'Languages' or 'Speaking Languages'")
    certifications: List[DocLine] = Field(description="Professional or technical certifications with issuing body and date (e.g., 'AWS Certified Solutions Architect - 2023') - under 'Certifications' or 'Accreditations'")
    soft_skills: List[DocLine] = Field(description="Verbatim Non-technical competencies (e.g., 'Leadership', 'Conflict Resolution', 'Agile Mindset') - often grouped under 'Skills', 'Core Competencies', or 'Soft Skills'")
    experiences: List[DocLine] = Field(description="List of lines of the document decribing professional work tasks from, job experiences, roles, and optional projects - under heading 'Work Experience' or 'Professional History'")
    text_languaje: Literal['Spanish', 'Catalan', 'English', None] = Field(default=None, description="Primary language of the document. *Infer from lexical patterns and section headers.*")    
    gender: Literal['Male', 'Female', None] = Field(default=None, description="Candidate's gender. *infer from explicit pronoun usage ('he/him', 'she/her'), name-gender associations (e.g., 'Susan', 'Mohamed'), or direct statements.* If ambiguous or unstated, use 'None'.")


cv_schema_json = json.dumps(CVData.model_json_schema(), indent=2, ensure_ascii=False)

resumee_extractor_prompt = """You are a precise, professional CV line extractor agent. Your task is to extract verbatim text lines from a CV and classify them into correct structured fields.

⚠️ STRICT RULES:
- DO NOT alter, paraphrase, abbreviate, or correct any line. Preserve original formatting, typos, and casing.
- DO NOT change or fabricate `node_id`. Every `node_id` must be verbatim from the original.
- `text_languaje` must be inferred strictly from section headers and lexical cues (e.g., "Experiencia Laboral" → Spanish).
- `gender` should only be inferred if explicitly stated (e.g., "she/her", "he/him", pronouns, or culturally strong name-gender mappings like 'Maria' → Female). Otherwise → 'Other'.
- If uncertain about field classification, assign to `professional_summary`.
- Use only the exact `node_id` strings provided in the input. Never invent or modify them.
- You **MUST** assign a value to `text_languaje`. Default to 'None' only if absolutely no linguistic clues exist.
- You **MUST** assign a value to `gender`. Default to 'None' unless clear evidence exists (pronouns, name associations, etc.)

Input is a list of dictionaries, each with:
  - `node_id`: unique identifier (e.g., "654")
  - `text`: raw plain-text content of that line
"""

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 20, "callbacks": [CallbackHandler()]}

def check_node_ids(cvdata: CVData, cv_content_dict: dict) -> bool:
    """Checks if all the node_ids extracted by the llm are real"""
    extracted_ids = []
    
    def traverse(obj):
        nonlocal extracted_ids
        if isinstance(obj, dict):
            # Check if current object has node_id key
            if 'node_id' in obj:
                extracted_ids.append(obj['node_id'])
            # Recursively traverse all values
            for k,v in obj.items():
                traverse(v)
            
        elif isinstance(obj, list):
            # If it's a list, traverse each element
            for item in obj:
                traverse(item)
    
    # Start traversal from the root
    traverse(cvdata)
    
    content_ids = [i['node_id'] for i in cv_content_dict]

    fakeids = list(set(extracted_ids) - set(content_ids))

    if fakeids:
        print(f"⚠️ The task is rejected because {fakeids} are fake")
        return False
    else:
        print("✅ All node_Ids are real")
        return True

def extract_CVData(content:dict) -> CVData:
    """Agente que analiza un curriculum y extrae información"""

    content = str(content)
    chars = max(1,len(content))

    llm = ChatOllama(model='qwen3', format="json", reasoning=False, num_ctx=32768, num_predict=chars, 
        temperature=0.0,  top_p=0.1, top_k=20, repeat_penalty=1.1, seed=42)
    
    try:
        cvdata = llm.with_structured_output(CVData).invoke(
            input = [
                SystemMessage(content=resumee_extractor_prompt),
                HumanMessage(content=content)
            ],
            config = config)  

        return cvdata  

    except Exception as e:
        print(f"Error: {e}")
        raise

# Check if the output JSON file exists
if os.path.exists(cv_original_json):
    print(f"Loading extracted CV data from {cv_original_json}...")
    with open(cv_original_json, "r", encoding="utf-8") as f:
        cv_extracted = json.load(f)

    check_node_ids(cv_extracted, cv_content_indexed)

else:
    print("Extracting CV data from scratch...")

    cv_extracted = extract_CVData(content=cv_content_indexed).model_dump()
    check_node_ids(cv_extracted, cv_content_indexed)

    print(f"Saving CV data to {cv_original_json}...")
    os.makedirs("data", exist_ok=True)
    with open(cv_original_json, "w", encoding="utf-8") as f:
        json.dump(cv_extracted, f, ensure_ascii=False, indent=2)

print(cv_extracted['name'], cv_extracted['professional_title'])

# %%
# 5. Define keywords Extracton from a text using LLM

keyword_extractor_prompt = """You are given a sentence as input. 
Your task is to identify and highlight **in bold (using Markdown syntax `**`)** any relevant **keywords** and Acronyms.

⚠️ STRICT RULES:
- Do **not** alter the original sentence in any way.
- Do **not** translate, correct, rephrase, or change any words.
- Do **not** add explanations or comments.
- Only return the sentence with the relevant keywords **bolded**.
- If a word appears multiple times and is relevant, bold **all occurrences**.
- If no keywords from these domains are found, return the sentence unchanged.

/no_think"""

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

class StringResponse(BaseModel):
    response: str

def extract_keywords(content:str) -> str:
    """Agente que extrae las keywords de un texto"""
    
    llm = ChatOllama(model='qwen3', reasoning=False, 
    num_ctx=512, temperature=0.5,  top_p=0.9, top_k=50, repeat_penalty=1.0, seed=42, num_predict=len(content))
    try:
        response = llm.with_structured_output(StringResponse).invoke(
            input = [SystemMessage(content=keyword_extractor_prompt),
                HumanMessage(content=content)
            ],
            config = config).response

        return list({v.lower() for k,v in enumerate(response.split('**')) if k%2==1})

    except Exception as e:
        print(f"Error: {e}")
        raise

# content = 'Experiencia contrastada en redacción y elaboración de propuestas técnicas y comerciales para licitaciones relativas a desarrollo de proyectos informáticos (especialmente en licitaciones para el CTTI)'
# content = 'Identificación de posibles incompatibilidades entre requisitos planteados. ambigüedades e inconsistencias en requisitos'
# print(extract_keywords(content))

# %%
# 5.1 Extract keywords from JobOffer 

def process_keywords(texts: list[str]) -> list[str]:

    keywords = []

    for text in texts:
        kw = extract_keywords(text)
        print(text, kw)
        keywords += kw

    return list(set(keywords))

# Check if the output JSON file exists
try:
    # raise Exception()
    with open(job_offer_json, "r", encoding="utf-8") as f:
        job_offer = json.load(f)
        exists = job_offer['keywords']
        print(f"Loading JobOffer requeriments keywords from {job_offer_json}...")
        print(job_offer['keywords'])
except:
    print("Extracting JobOffer requeriments keywords from scratch...")
    job_offer['keywords'] = process_keywords(
        job_offer['job_functions']
        +job_offer['job_requirements']
        +[job_offer['company_description']])

    print(f"Saving JobOffer requeriments keywords to {job_offer_json}...")
    with open(job_offer_json, "w", encoding="utf-8") as f:
        json.dump(job_offer, f, ensure_ascii=False, indent=2)

# %%
# 6. Definition of keywords Assingation for a text using LLM

kw_selector_prompt = """You are a semantic keyword matching agent. Your task is to analyze input text and return a subset of predefined keywords that best match the content by meaning.

## Rules (STRICT - DO NOT VIOLATE)
1. **Only use keywords from the provided keyword_list** - Never invent, modify, or adapt keywords
2. **Semantic matching allowed** - Keywords don't need to appear exactly in the text; match by meaning/context
3. **Completeness matching** - Add keywords that logically complete the meaning even if not explicitly stated
4. **No extraction** - Do not extract new keywords from the text itself
5. **Output format** - Return ONLY a JSON array of matched keywords

## Matching Guidelines
- Consider synonyms, related concepts, and contextual implications
- If the text discusses a concept that aligns with a keyword's meaning, include it
- If adding a keyword would "complete the picture" of what the text implies, include it
- Be selective - only include keywords with strong semantic alignment

## Example
**Keyword List:** ["technology", "innovation", "growth", "sustainability", "collaboration"]

**Input Text:** "Our team worked together to develop new solutions that will help the company expand while being environmentally responsible."

**Output:**
```json
["collaboration", "innovation", "growth", "sustainability"]
```

## keywords_list: 

{keywords_list}

"""

class KeywordsFit(BaseModel):
    keywords: list[str] =  Field(description="best fit keywords in keywords_list")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3:14b', reasoning=False, 
    num_ctx=2048, temperature=0.0,  num_predict=100, top_p=0.0, top_k=10, repeat_penalty=1.1, seed=42)

def select_keywords(content, keywords_list) -> list:
    """Agente que elije el mejor match de un keyword de una tarea"""
    try:
        result = llm.with_structured_output(KeywordsFit).invoke(
            input = [SystemMessage(content=kw_selector_prompt.format(keywords_list=keywords_list)),
                HumanMessage(content=content)
            ],
            config = config)    

        return [kw for kw in result.keywords if kw.lower() in keywords_list]

    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
# 6.1 Assign keywords to a resumme job experience loop
import re

def assing_keywords(cv_adapted: dict, job_offer: dict) -> dict:

    # Filtro: Más de 3 letras separadas y un espacio
    minleters = r'[a-zA-Z]{4,}\s'

    assigned_kw = []
    for task in cv_adapted['experiences']:
        keywords = [None]
        min_len_w = len(re.findall(minleters, task['text'], re.UNICODE))
        is_header = task['text'].startswith('#')
        if min_len_w > 2 and not is_header: 
            # keywords = select_keywords(task['text'], set(job_offer['keywords'])-set(assigned_kw))
            keywords = select_keywords(task['text'], set(job_offer['keywords']))
            task['keywords'] = keywords
            print(task)
            assigned_kw += keywords

    print(f'assigned: {len(assigned_kw)}, of: {len(job_offer['keywords'])}')
    return cv_adapted

try:
    # raise Exception()
    with open(cv_adapted_json, "r", encoding="utf-8") as f:
        cv_adapted = json.load(f)
        exists = [e for e in cv_adapted['experiences'] if 'keywords' in e]
        exists[0]['keywords']
        print(f"Loading keywords assignments to CV from {cv_adapted_json}...")
        [print(exp['text'], exp['keywords']) for exp in exists ]

except:
    print("Generating keywords assignments to CV from scratch...")
    cv_adapted = assing_keywords(cv_extracted, job_offer)

    print(f"Saving keywords assignments to {cv_adapted_json}...")
    with open(cv_adapted_json, "w", encoding="utf-8") as f:
        json.dump(cv_adapted, f, ensure_ascii=False, indent=2)

# %%
# 7. Definiiton Adapt resumee job experience task with selected keywords using LLM
import re

text_adapter_prompt = """You are an expert resume optimization agent. 
Your task is to adapt a single line of a CV to include specific keywords while preserving the original meaning and approximate length.

Input Format:
You will receive a JSON object: {{"text": "original_sentence", "keywords": ["keyword1", "keyword2", ...]}}

Instructions:
1. Rewrite the text to naturally incorporate ONLY the most relevant keywords from the list (maximum 3-5 keywords).
2. Prioritize keywords that match the context of the original text - do not force irrelevant keywords.
3. Ensure the adapted sentence has a length similar to the original (±20%).
4. Do not change the core meaning of the original sentence; only modify what is necessary to include keywords.
5. Highlight every used keyword in the output using Markdown bold syntax (e.g., **keyword**).
6. Use {language} language in your response.
7. If no keywords fit naturally, return the original text unchanged.
"""

class AdaptResponse(BaseModel):
    adapted_text: str = Field(description="Corrected text using all the **keywords**.")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

def select_relevant_keywords(text: str, keywords: List[str], max_ratio: float = 0.1) -> List[str]:
    """Select only the most relevant keywords based on text length and relevance"""
    word_count = len(re.findall(r'\b\w+\b', text))
    max_keywords = max(3, int(word_count * max_ratio))  # 10% of words, minimum 3
    
    text_lower = text.lower()
    
    # Score keywords by relevance
    scored_keywords = []
    for kw in keywords:
        kw_lower = kw.lower()
        score = 0
        
        # Exact match in text gets high priority
        if kw_lower in text_lower:
            score += 10
        
        # Partial match (word contains keyword or vice versa)
        if any(kw_lower in word or word in kw_lower for word in text_lower.split()):
            score += 5
        
        # # Category relevance (technical keywords for IT resumes)
        # technical_terms = ['cloud', 'arquitectura', 'desarrollo', 'proyectos', 'gestión', 'servicios', 'itil', 'devops', 'api', 'docker', 'microservicios']
        # if any(term in kw_lower for term in technical_terms):
        #     score += 3
        
        scored_keywords.append((kw, score))
    
    # Sort by score and remove duplicates
    scored_keywords = sorted(scored_keywords, key=lambda x: x[1], reverse=True)
    seen = set()
    selected = []
    
    for kw, _ in scored_keywords:
        kw_normalized = kw.lower().strip()
        if kw_normalized not in seen and kw_normalized:
            seen.add(kw_normalized)
            selected.append(kw)
        
        if len(selected) >= max_keywords:
            break
    
    return selected

def adapt_text(content, language) -> str:
    """Agente que adapta un texto reescribiendolo con las keywords"""
    
    llm = ChatOllama(model='qwen3:14b', reasoning=False, num_ctx=4096, num_predict=len(str(content)), temperature=0.2,  top_p=0.9, top_k=40, repeat_penalty=1.25, seed=42)
    try:
        if not 'keywords' in content or not content['keywords']: return None

        content['keywords'] = select_relevant_keywords(content['text'], content['keywords'])
        result = llm.with_structured_output(AdaptResponse).invoke(
            input = [
                SystemMessage(content=text_adapter_prompt.format(language=language)),
                HumanMessage(content=str(content))
            ],
            config = config)    

        return result.adapted_text

    except Exception as e:
        print(f"Error: {e}")
        return None

content = {'node_id': 323, 
    'text': '- Proyecto de gestión centralizada de Aparcamientos en CLOUD: diseño de arquitectura e implementación de sistemas modulares para la gestión de 43 aparcamientos integrados en CLOUD AWS basado en DOCKER, microservicios API REST sobre WSO2. ', 
    'keywords': ['cloud', 'arquitectura empresarial', 'gestión de proyectos', 'proyectos informáticos', 'desarrollo', 'automatizar', 'procesos', 'gestión de servicios tic', 'itil', 'secdevops', 'cloud', 'microsoft', 'proyectos', 'desarrollar', 'precisión', 'análisis'], 
    # 'adaptation': '- Proyecto de **gestión de proyectos** y **desarrollo** de un sistema centralizado de **aparcamientos en **cloud**, basado en **proyectos informáticos** y **secdevops**, donde diseñé la **arquitectura empresarial** para la **gestión de servicios tic** mediante **automatizar** procesos de **precisión** en 43 aparcamientos integrados en **cloud** AWS, con **itil** y **microsoft**.'
}

# adapt_text(content, 'Spanish')
# OUTPUT: '- Proyecto de **gestión de proyectos** y **desarrollo** de un sistema centralizado de **aparcamientos en CLOUD**: diseño de **arquitectura empresarial** e implementación de sistemas modulares para la gestión de 43 aparcamientos integrados en **cloud** AWS basado en DOCKER, microservicios API REST sobre WSO2, con enfoque en **procesos** de **automatizar** y **precisión** en **proyectos informáticos**, aplicando principios de **ITIL** y **SecDevOps** para la **gestión de servicios TIC** y **desarrollar** soluciones con **microsoft** y **precisión** en el **análisis**.'

# %%
# 7.1. Adapt resumee job experience task with selected keywords using LLM

# Check if the output JSON file exists
try:
    # raise Exception()
    with open(cv_adapted_json, "r", encoding="utf-8") as f:
        cv_adapted = json.load(f)
        adap = [e for e in cv_adapted['experiences'] if 'adaptation' in e]
        exists = adap[0]['adaptation']
        print(f"Loading adapted tasks based on keywords from {cv_adapted_json}...")
        [print(exp) for exp in cv_adapted['experiences']]

except:
    print("Generating adapted tasks based on keywords from scratch...")

    for exp in cv_adapted['experiences']:
        new_text = adapt_text(exp, job_offer['language'])
        if (new_text is not None and new_text != exp['text']):
            exp['adaptation'] = new_text
            print(exp)

    print(f"Saving adapted tasks based on keywords to {cv_adapted_json}...")
    with open(cv_adapted_json, "w", encoding="utf-8") as f:
        json.dump(cv_adapted, f, ensure_ascii=False, indent=2)

# %%
# 8. Assing keywords to resumee soft skill using LLM

prompt = """
Eres un experto en semántica y lingüística. Tu tarea es relacionar cada término de la 'Lista A' con su equivalente significativo en la 'Lista B'.
Los términos pueden estar expresados de forma diferente (sinónimos, jerga, descripciones), pero deben coincidir en significado.

Reglas:
1. Cada término de la Lista A debe tener máximo una coincidencia en la Lista B.
2. Si un término de la Lista A no tiene relación con nada en la Lista B, asigna null al valor correspondiente.
3. Devuelve ÚNICAMENTE un objeto JSON válido. No incluyas texto explicativo antes ni después.
4. El formato JSON debe ser una lista de objetos: [{{"origen": "term_a", "coincidencia": "term_b"}}, ...]

Lista A: {skills}
Lista B: {keywords}

Responde solo con el JSON:
"""

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=1024, temperature=0.1,  top_p=0.5, top_k=40, repeat_penalty=1.1, seed=42)

def match_skills_bulk(skills, keywords_set):
    """
    Utiliza un LLM local vía Ollama para encontrar relaciones semánticas
    entre dos listas de términos.
    """
    class MatchResponse(BaseModel):
        node_id: Literal[*[e['node_id'] for e in skills]] = Field(description="node_id of text, keep it as it comes")
        text: Literal[*[e['text'] for e in skills]] = Field(description="Find the best kayword mach for every single text")
        keywords: Literal[*list(keywords_set)] = Field(description="Best fit keyword for text in the field of computer science and project management")

    class ListResponse(BaseModel):
        listitems: List[MatchResponse] = Field(description="lista de equivalencias")

    try:
        # Llamada a Ollama local
        return llm.with_structured_output(ListResponse).invoke(
            input = [
                # SystemMessage(content=skill_extractor_prompt.format(keywords=keywords)),
                HumanMessage(content=prompt.format(skills=skills, keywords=keywords_set))
            ],
            config = config)
        
    except Exception as e:
        print(e)
        return None

def assign_soft_skill_keyword():

    skills_list = cv_adapted['soft_skills'] #+ base_skills_list 
    print(skills_list)
    print('-'*100)
    print(job_offer['keywords'])
    print('-'*100)

    relaciones = match_skills_bulk(skills_list, job_offer['keywords'])
    cv_adapted['soft_skills'] = [i.model_dump() for i in relaciones.listitems]


# Check if the output JSON file exists
try:
    with open(cv_adapted_json, "r", encoding="utf-8") as f:
        cv_adapted = json.load(f)
        exists = [skill for skill in cv_adapted['soft_skills'] if 'keywords' in skill]
        exists[0]['keywords']
        print(f"Loading soft skills keywords from {cv_adapted_json}...")
        [print(skill['text'],' ==>', skill['keywords']) for skill in exists]

except:
    print("Generating soft skills keywords from scratch...")
    assign_soft_skill_keyword()

    print(f"Saving soft skills keywords to {cv_adapted_json}...")
    with open(cv_adapted_json, "w", encoding="utf-8") as f:
        json.dump(cv_adapted, f, ensure_ascii=False, indent=2)

for sk in cv_adapted['soft_skills']: print(sk['text'], "  ==>  ",sk['keywords'])

# %%
# 9. Adapt resumee soft skill using selected keywords

text_adapter_prompt = """You are a professional resume writer and text editor.

You have to express '{soft_skill}' in a way that contains '{keywords}'.

**Instructions**:
1. **Preserve meaning** while incorporating all provided **keywords** naturally.
2. Be concise, do not explain. do not elavorate.
3. **Translate and rewrite** the text **in {language} only**.
4. **Summarize and synthesize** the text to **at most {max_words} words** — keep it concise and impactful.
5. If no keywords are provided, only translate and slightly polish the text in {language}.

Output strictly as plain text. Do NOT include explanations or metadata.

/no_think"""

class AdaptResponse(BaseModel):
    adapted_text: str = Field(description="The final rewritten resume bullet point.")

config = {"configurable": {"thread_id": "resumee_research"}, "recursion_limit": 4, "callbacks": [CallbackHandler()]}

llm = ChatOllama(model='qwen3', reasoning=False, num_ctx=4096, num_predict=100, temperature=0.2,  top_p=0.9, top_k=40, repeat_penalty=1.1, seed=42)

def adapt_soft_skill(content, keywords, language) -> str:
    """Agente que adapta un texto reescribiendolo con las keywords"""
    try:
        prompt = text_adapter_prompt.format(soft_skill=content, language=language, max_words=len(content.split())*2, keywords=keywords)
            
        result = llm.with_structured_output(AdaptResponse).invoke(
            input = [
                SystemMessage(content=prompt),
                HumanMessage(content=content)
            ],
            config = config)    

        return result.adapted_text

    except Exception as e:
        print(f"Error: {e}")
        return content


def adapt_soft_skills_loop(cv_adapted, language):
    for skill in cv_adapted['soft_skills']:
        is_header = skill['text'].startswith('#')
        if 'keywords' in skill and not is_header: 
            skill['adaptation'] = adapt_soft_skill(skill['text'], skill['keywords'], language)
            print(skill['text'],' ==>', skill['adaptation'])

# Check if the output JSON file exists
try:
    # raise Exception()
    with open(cv_adapted_json, "r", encoding="utf-8") as f:
        cv_adapted = json.load(f)
        exists = [skill for skill in cv_adapted['soft_skills'] if 'adaptation' in skill]
        exists[0]['adaptation']
        print(f"Loading soft skills adaptations from {cv_adapted_json}...")
        [print(skill['text'],' ==>', skill['adaptation']) for skill in exists]


except:
    print("Generating soft skills adaptations from scratch...")
    adapt_soft_skills_loop(cv_adapted, job_offer['language'])

    print(f"Saving soft skills adaptations to {cv_adapted_json}...")
    with open(cv_adapted_json, "w", encoding="utf-8") as f:
        json.dump(cv_adapted, f, ensure_ascii=False, indent=2)

# %%
# 10. Edit new version of the resumee
def extract_adaptations_dynamic(data):
    """
    Extracts all adaptations from the CV data dynamically by traversing the tree structure
    and returns them as a list of dictionaries ordered by node_id in descending order.
    
    Args:
        data (dict): The CV data structure
        
    Returns:
        list: List of dictionaries with 'node_id' and 'adaptation' keys, ordered by node_id descending
    """
    adaptations = {}
    
    def traverse(obj, parent_key=None):
        if isinstance(obj, dict):
            # Check if current object has adaptation key
            if 'adaptation' in obj and 'node_id' in obj:
                adaptations[obj['node_id']]= obj['adaptation']
            
            # Recursively traverse all values
            for key, value in obj.items():
                traverse(value, key)
        elif isinstance(obj, list):
            # If it's a list, traverse each element
            for item in obj:
                traverse(item, parent_key)
    
    # Start traversal from the root
    traverse(data)
    
    # Sort by node_id in descending order
    return adaptations
    
from tools import odt_tools
from IPython.display import Markdown

adaptations = extract_adaptations_dynamic(cv_adapted)

cv_document = odt_tools.OdtDocument(cv_original_file_path)
cv_document.replace(adaptations)
cv_document.save(cv_adapted_odt)

# display(Markdown(cv_document.get_text(markdown=True)))
print(cv_document.get_text(markdown=False))
